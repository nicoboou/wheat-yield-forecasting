# %% [markdown]
# # Table of Contents

# %% [markdown]
# -  [About the dataset](#about)<br>
# -  [Load the data](#load_data)<br>

# %% [markdown]
# # Imports

# %%
# for package auto reload
# %load_ext autoreload
# %autoreload 2

# for better rendering of plots in jupyter notebook
# %matplotlib inline

# %%
# base modules
import os
import sys
import copy
import logging
from collections import OrderedDict

# for manipulating data
import numpy as np
import pandas as pd
import math
import dill

# for Machine Learning
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, plot_tree
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV
from sklearn.calibration import CalibratedClassifierCV
from sklearn.inspection import permutation_importance
from scipy.cluster import hierarchy

#for Time-Series Statistical Analysis
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA

# for visualization
from IPython.display import display
from matplotlib import pyplot as plt
import graphviz
import streamlit as st
import plotly.express as px
# seaborn
# altair


# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings('ignore')

#display all columns
pd.options.display.max_columns = None

# %%
# path to repo
path_to_repo = os.getcwd()
path_to_repo
# Out:
# '/Users/nicolas/Desktop/Etudes/3_emlyon/2021:2022/Machine_Learning/project/notebook'

# %% [markdown]
# # Introduction: Crops Yield Project

# %% [markdown]
# ### Project Ideas

# %% [markdown]
# Several ideas might pop up looking at this dataset, for example:
#
# **Exploratory Data Analysis**
# - Vizualisation of certain crops yields' temporal evolution per country
# - Correlation between production & population
#
# **Machine Learning**
# - C02 emissions of crops using regression
# - Clustering on CO2 crop emissioners
# - Crop yields forecasting through time-series analysis using production & pop correlation

# %% [markdown]
# # Datasets Overview

# %% [markdown]
# ## 1. Agricultural Crop Production

# %% [markdown]
# ### Summary

# %% [markdown]
# Crop statistics for 173 products in Africa, America, Asia, Europe and Oceania, collected from 1961 to 2019.

# %% [markdown]
# ### Description

# %% [markdown]
# Data from the Food and Agriculture Organization of the United Nations (FAO)
# <br/><br/>Achieving food security for all is at the heart of FAO's efforts - ensuring that people have regular access to enough quality food to lead active and healthy lives. Our three main objectives are: the eradication of hunger, food insecurity and malnutrition; the eradication of poverty and the promotion of economic and social progress for all; and the sustainable management and use of natural resources, including land, water, air, climate and genetic resources, for the benefit of present and future generations.
# <br/><br/>Primary crops, fibre crops. Crop statistics are recorded for 173 commodities, covering the following categories: Primary crops, Primary fibre crops, Cereals, Secondary cereals, Citrus, Fruit, Jute and related fibres, Oilcake equivalent, Primary oilseeds, Dry vegetables, Roots and tubers, Green fruits and vegetables and Melons. Data are expressed in terms of area harvested, quantity produced, yield and quantity of seed. The aim is to provide comprehensive coverage of production of all primary crops for all countries and regions of the world.<br/><br/>
# Source : Organisation des Nations Unies pour l'alimentation et l'agriculture (FAO)

# %% [markdown]
# ## 2. Gas emissions Statistics

# %% [markdown]
# ### Summary

# %% [markdown]
# The FAOSTAT domain Emissions Totals disseminates information estimates of CH4, N2O and CO2 emissions/removals and their aggregates in CO2eq in units of kilotonnes (kt, or 106 kg).

# %% [markdown]
# ### Description

# %% [markdown]
# The FAOSTAT domain Emissions Totals summarizes the greenhouse gas (GHG) emissions disseminated in the FAOSTAT Climate Change Emissions domains, generated from agriculture and forest land. They consist of methane (CH4), nitrous oxide (N2O) and carbon dioxide (CO2) emissions from crop and livestock activities, forest management and include land use and land use change processes. Data are computed at Tier 1 of the IPCC Guidelines for National greenhouse gas (GHG) Inventories (IPCC, 1996; 1997; 2000; 2002; 2006; 2014). Estimates are available by country, with global coverage for the period 1961–2019 with projections for 2030 and 2050 for some categories of emissions or 1990–2019 for others. The database is updated annually.

# %% [markdown]
# ## 3. Population per country

# %% [markdown]
# The FAOSTAT Population module contains time series data on population, by sex and urban/rural. The series consist of both estimates and projections for different periods as available from the original sources, namely:
# 1. Population data refers to the World Population Prospects: The 2019 Revision from the UN Population Division.
# 2. Urban/rural population data refers to the World Urbanization Prospects: The 2018 Revision from the UN Population Division.

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## 1. Load the *Agricultural Crop data*

# %% [markdown]
# ### Get a glimpse of one of the main datasets

# %%
# Loading Africa's dataset

url = 'https://raw.githubusercontent.com/nicoboou/ml_eml/main/data/agriculture-crop-production/Production_Crops_E_Africa.csv'
crops_africa = pd.read_csv(url, sep=',',encoding='latin-1')
crops_africa.head(10)
# Out:
#    Area Code     Area  Item Code                 Item  Element Code  \
# 0          4  Algeria        221  Almonds, with shell          5312
# 1          4  Algeria        221  Almonds, with shell          5419
# 2          4  Algeria        221  Almonds, with shell          5510
# 3          4  Algeria        515               Apples          5312
# 4          4  Algeria        515               Apples          5419
# 5          4  Algeria        515               Apples          5510
# 6          4  Algeria        526             Apricots          5312
# 7          4  Algeria        526             Apricots          5419
# 8          4  Algeria        526             Apricots          5510
# 9          4  Algeria        366           Artichokes          5312
#
#           Element    Unit    Y1961 Y1961F    Y1962 Y1962F    Y1963 Y1963F  \
# 0  Area harvested      ha  13300.0      F  13300.0      F  13300.0      F
# 1           Yield   hg/ha   4511.0     Fc   4511.0     Fc   4511.0     Fc
# 2      Production  tonnes   6000.0    NaN   6000.0    NaN   6000.0    NaN
# 3  Area harvested      ha   3400.0      F   3100.0      F   2800.0      F
# 4           Yield   hg/ha  45294.0     Fc  45161.0     Fc  46429.0     Fc
# 5      Production  tonnes  15400.0    NaN  14000.0    NaN  13000.0    NaN
# 6  Area harvested      ha   4200.0      F   4600.0      F   4000.0      F
# 7           Yield   hg/ha  30286.0     Fc  30000.0     Fc  30000.0     Fc
# 8      Production  tonnes  12720.0    NaN  13800.0    NaN  12000.0    NaN
# 9  Area harvested      ha   5000.0      F   5000.0      F   5000.0      F
#
#      Y1964 Y1964F    Y1965 Y1965F    Y1966 Y1966F    Y1967 Y1967F    Y1968  \
# 0  14200.0      F  13800.0      F  12700.0      F  12900.0      F  10000.0
# 1   4507.0     Fc   4493.0     Fc   4488.0     Fc   4510.0     Fc   4497.0
# 2   6400.0    NaN   6200.0    NaN   5700.0    NaN   5818.0    NaN   4497.0
# 3   2700.0      F   2900.0      F   2500.0      F   2500.0      F   2300.0
# 4  46078.0     Fc  45348.0     Fc  44832.0     Fc  45456.0     Fc  45609.0
# 5  12441.0    NaN  13151.0    NaN  11208.0    NaN  11364.0    NaN  10490.0
# 6   4200.0      F   4000.0      F   3900.0      F   4500.0      F   3800.0
# 7  35476.0     Fc  34273.0     Fc  29810.0     Fc  29100.0     Fc  30218.0
# 8  14900.0    NaN  13709.0    NaN  11626.0    NaN  13095.0    NaN  11483.0
# 9   4520.0    NaN   5700.0    NaN   5080.0    NaN   4460.0    NaN   5270.0
#
#   Y1968F    Y1969 Y1969F    Y1970 Y1970F    Y1971 Y1971F    Y1972 Y1972F  \
# 0      F   5500.0      F   6700.0      F   4600.0      F   8300.0      F
# 1     Fc   4484.0     Fc   4478.0     Fc   4500.0     Fc   4514.0     Fc
# 2    NaN   2466.0    NaN   3000.0    NaN   2070.0    NaN   3747.0    NaN
# 3      F   2600.0      F   2800.0      F   3000.0      F   2500.0      F
# 4     Fc  45681.0     Fc  46071.0     Fc  45020.0     Fc  45920.0     Fc
# 5    NaN  11877.0    NaN  12900.0    NaN  13506.0    NaN  11480.0    NaN
# 6      F   4000.0      F   4000.0      F   4300.0      F   4300.0      F
# 7     Fc  31190.0     Fc  35500.0     Fc  35114.0     Fc  29972.0     Fc
# 8    NaN  12476.0    NaN  14200.0    NaN  15099.0    NaN  12888.0    NaN
# 9    NaN   4040.0    NaN   4000.0    NaN   5010.0    NaN   3070.0    NaN
#
#      Y1973 Y1973F    Y1974 Y1974F    Y1975 Y1975F    Y1976 Y1976F    Y1977  \
# 0   9200.0      F  10150.0      F  11000.0      F  18250.0      F  10400.0
# 1   4502.0     Fc   4500.0     Fc   4542.0     Fc   4498.0     Fc   4487.0
# 2   4142.0    NaN   4567.0    NaN   4996.0    NaN   8208.0    NaN   4666.0
# 3   2200.0      F   3200.0      F   4300.0      F   3200.0      F   3800.0
# 4  45736.0     Fc  45525.0     Fc  50174.0     Fc  45700.0     Fc  50471.0
# 5  10062.0    NaN  14568.0    NaN  21575.0    NaN  14624.0    NaN  19179.0
# 6   3600.0      F   4500.0      F   6500.0      F   6000.0      F   9200.0
# 7  30253.0     Fc  29540.0     Fc  34977.0     Fc  34722.0     Fc  30008.0
# 8  10891.0    NaN  13293.0    NaN  22735.0    NaN  20833.0    NaN  27607.0
# 9   3470.0    NaN   4090.0    NaN   4310.0    NaN   4730.0    NaN   3210.0
#
#   Y1977F    Y1978 Y1978F    Y1979 Y1979F    Y1980 Y1980F    Y1981 Y1981F  \
# 0      F   7100.0      F   8100.0      F   8700.0      F  15960.0    NaN
# 1     Fc   4496.0     Fc   4483.0     Fc   4483.0     Fc   4969.0     Fc
# 2    NaN   3192.0    NaN   3631.0    NaN   3900.0    NaN   7930.0    NaN
# 3      F   3200.0      F   3000.0      F   4300.0      F   4600.0      F
# 4     Fc  48678.0     Fc  45520.0     Fc  50740.0     Fc  50839.0     Fc
# 5    NaN  15577.0    NaN  13656.0    NaN  21818.0    NaN  23386.0    NaN
# 6      F   7300.0      F   8700.0      F   7700.0      F  12000.0      F
# 7     Fc  29888.0     Fc  34703.0     Fc  30240.0     Fc  35343.0     Fc
# 8    NaN  21818.0    NaN  30192.0    NaN  23285.0    NaN  42412.0    NaN
# 9    NaN   3310.0    NaN   3780.0    NaN   2670.0    NaN   1930.0    NaN
#
#      Y1982 Y1982F    Y1983 Y1983F    Y1984 Y1984F    Y1985 Y1985F    Y1986  \
# 0  15450.0    NaN  18030.0    NaN  16490.0    NaN  21100.0    NaN  20860.0
# 1   4296.0     Fc   3934.0     Fc   4534.0     Fc   4716.0     Fc   3864.0
# 2   6637.0    NaN   7093.0    NaN   7476.0    NaN   9951.0    NaN   8060.0
# 3   4900.0      F   4800.0      F   7800.0      F   8000.0      F   8000.0
# 4  49951.0     Fc  49825.0     Fc  49810.0     Fc  53000.0     Fc  50874.0
# 5  24476.0    NaN  23916.0    NaN  38852.0    NaN  42400.0      *  40699.0
# 6  11000.0      F  10000.0      F  12000.0      F  13000.0      F   9300.0
# 7  36269.0     Fc  60519.0     Fc  45532.0     Fc  32622.0     Fc  39820.0
# 8  39896.0    NaN  60519.0    NaN  54638.0    NaN  42408.0    NaN  37033.0
# 9   1340.0    NaN   1700.0    NaN   2010.0    NaN    800.0    NaN    830.0
#
#   Y1986F    Y1987 Y1987F    Y1988 Y1988F    Y1989 Y1989F    Y1990 Y1990F  \
# 0    NaN  21000.0    NaN  21370.0    NaN  23610.0    NaN  25010.0    NaN
# 1     Fc   3930.0     Fc   4528.0     Fc   5268.0     Fc   4691.0     Fc
# 2    NaN   8253.0    NaN   9676.0    NaN  12438.0    NaN  11733.0    NaN
# 3      F   8700.0      F   8000.0      F  10200.0      F  10740.0    NaN
# 4     Fc  50216.0     Fc  49975.0     Fc  50387.0     Fc  36258.0     Fc
# 5    NaN  43688.0    NaN  39980.0    NaN  51395.0    NaN  38941.0    NaN
# 6      F  10500.0      F  10200.0      F  14300.0      F  14010.0    NaN
# 7     Fc  34695.0     Fc  31863.0     Fc  32115.0     Fc  24967.0     Fc
# 8    NaN  36430.0    NaN  32500.0    NaN  45925.0    NaN  34979.0    NaN
# 9    NaN   1370.0    NaN   1310.0    NaN   1170.0    NaN   1170.0    NaN
#
#      Y1991 Y1991F    Y1992 Y1992F    Y1993 Y1993F    Y1994 Y1994F    Y1995  \
# 0  24240.0    NaN  24970.0    NaN  25880.0    NaN  26130.0    NaN  24860.0
# 1   6505.0     Fc   7169.0     Fc   9538.0     Fc   7312.0     Fc   7992.0
# 2  15768.0    NaN  17901.0    NaN  24685.0    NaN  19106.0    NaN  19869.0
# 3  10960.0    NaN  11140.0    NaN  12020.0    NaN  11800.0    NaN  11930.0
# 4  43638.0     Fc  55641.0     Fc  52753.0     Fc  41777.0     Fc  53764.0
# 5  47827.0    NaN  61984.0    NaN  63409.0    NaN  49297.0    NaN  64140.0
# 6  12010.0    NaN  12290.0    NaN  12560.0    NaN  13170.0    NaN  13040.0
# 7  49345.0     Fc  33186.0     Fc  55085.0     Fc  32414.0     Fc  31620.0
# 8  59263.0    NaN  40785.0    NaN  69187.0    NaN  42689.0    NaN  41233.0
# 9   1110.0    NaN    880.0    NaN    630.0    NaN    670.0    NaN    860.0
#
#   Y1995F    Y1996 Y1996F    Y1997 Y1997F    Y1998 Y1998F    Y1999 Y1999F  \
# 0    NaN  25190.0    NaN  27440.0    NaN  26490.0    NaN  26820.0    NaN
# 1     Fc  13323.0     Fc   7069.0     Fc   8169.0     Fc   9546.0     Fc
# 2    NaN  33561.0    NaN  19396.0    NaN  21641.0    NaN  25602.0    NaN
# 3    NaN  12190.0    NaN  12260.0    NaN  12870.0    NaN  13020.0    NaN
# 4     Fc  60598.0     Fc  53446.0     Fc  58574.0     Fc  67065.0     Fc
# 5    NaN  73869.0    NaN  65525.0    NaN  75385.0    NaN  87318.0    NaN
# 6    NaN  13460.0    NaN  13770.0    NaN  13680.0    NaN  13950.0    NaN
# 7     Fc  59435.0     Fc  28940.0     Fc  42478.0     Fc  53147.0     Fc
# 8    NaN  80000.0    NaN  39850.0    NaN  58110.0    NaN  74140.0    NaN
# 9    NaN   2590.0    NaN   3790.0    NaN   5390.0    NaN   3700.0    NaN
#
#      Y2000 Y2000F     Y2001 Y2001F     Y2002 Y2002F     Y2003 Y2003F  \
# 0  27150.0    NaN   26980.0    NaN   27720.0    NaN   30630.0    NaN
# 1   9754.0     Fc    9340.0     Fc   11648.0     Fc   10524.0     Fc
# 2  26483.0    NaN   25199.0    NaN   32287.0    NaN   32234.0    NaN
# 3  13480.0    NaN   14040.0    NaN   15240.0    NaN   18080.0    NaN
# 4  71600.0     Fc   74715.0     Fc   79421.0     Fc   74968.0     Fc
# 5  96517.0    NaN  104900.0    NaN  121038.0    NaN  135542.0    NaN
# 6  13390.0    NaN   13530.0    NaN   14660.0    NaN   16330.0    NaN
# 7  42087.0     Fc   50055.0     Fc   50295.0     Fc   66423.0     Fc
# 8  56354.0    NaN   67724.0    NaN   73733.0    NaN  108469.0    NaN
# 9   4140.0    NaN    3210.0    NaN    3200.0    NaN    2880.0    NaN
#
#       Y2004 Y2004F     Y2005 Y2005F     Y2006 Y2006F     Y2007 Y2007F  \
# 0   30453.0    NaN   35099.0    NaN   39098.0    NaN   40890.0    NaN
# 1   12473.0     Fc   12929.0     Fc   13728.0     Fc    8342.0     Fc
# 2   37985.0    NaN   45379.0    NaN   53673.0    NaN   34110.0    NaN
# 3   19861.0    NaN   24279.0    NaN   28658.0    NaN   31904.0    NaN
# 4   83265.0     Fc   82257.0     Fc   98835.0     Fc   59557.0     Fc
# 5  165372.0    NaN  199712.0    NaN  283242.0    NaN  190010.0    NaN
# 6   19375.0    NaN   22888.0    NaN   27362.0    NaN   31085.0    NaN
# 7   45415.0     Fc   63394.0     Fc   61040.0     Fc   37457.0     Fc
# 8   87991.0    NaN  145097.0    NaN  167017.0    NaN  116436.0    NaN
# 9    3316.0    NaN    2828.0    NaN    1713.0    NaN    1813.0    NaN
#
#       Y2008 Y2008F     Y2009 Y2009F     Y2010 Y2010F     Y2011 Y2011F  \
# 0   39787.0    NaN   39313.0    NaN   54485.0    NaN   52245.0    NaN
# 1    9933.0     Fc   12055.0     Fc   10457.0     Fc    9689.0     Fc
# 2   39521.0    NaN   47393.0    NaN   56973.0    NaN   50621.0    NaN
# 3   33206.0    NaN   36616.0    NaN   52419.0    NaN   51080.0    NaN
# 4   78590.0     Fc   73047.0     Fc   72233.0     Fc   79112.0     Fc
# 5  260967.0    NaN  267469.0    NaN  378637.0    NaN  404105.0    NaN
# 6   32849.0    NaN   34119.0    NaN   49495.0    NaN   49191.0    NaN
# 7   52485.0     Fc   59461.0     Fc   40098.0     Fc   58120.0     Fc
# 8  172409.0    NaN  202876.0    NaN  198467.0    NaN  285897.0    NaN
# 9    2304.0    NaN    2724.0    NaN    3112.0    NaN    3760.0    NaN
#
#       Y2012 Y2012F     Y2013 Y2013F     Y2014 Y2014F     Y2015 Y2015F  \
# 0   49975.0    NaN   49011.0    NaN   39050.0    NaN   40403.0    NaN
# 1   13304.0     Fc   12965.0     Fc   16601.0     Fc   18930.0     Fc
# 2   66487.0    NaN   63545.0    NaN   64827.0    NaN   76482.0    NaN
# 3   48828.0    NaN   48064.0    NaN   40418.0    NaN   41011.0    NaN
# 4   81414.0     Fc   94860.0     Fc  114507.0     Fc  110086.0     Fc
# 5  397529.0    NaN  455937.0    NaN  462815.0    NaN  451472.0    NaN
# 6   47376.0    NaN   46893.0    NaN   38590.0    NaN   38857.0    NaN
# 7   56845.0     Fc   68194.0     Fc   56217.0     Fc   75530.0     Fc
# 8  269308.0    NaN  319784.0    NaN  216941.0    NaN  293486.0    NaN
# 9    4168.0    NaN    4472.0    NaN    4705.0    NaN    4674.0    NaN
#
#       Y2016 Y2016F     Y2017 Y2017F     Y2018 Y2018F     Y2019 Y2019F
# 0   49983.0    NaN   50100.0    NaN   43043.0    NaN   35380.0    NaN
# 1   13223.0     Fc   12362.0     Fc   13292.0     Fc   20467.0     Fc
# 2   66095.0    NaN   61934.0    NaN   57213.0    NaN   72412.0    NaN
# 3   46070.0    NaN   44620.0    NaN   39034.0    NaN   32989.0    NaN
# 4  108716.0     Fc  110766.0     Fc  124970.0     Fc  169399.0     Fc
# 5  500855.0    NaN  494239.0    NaN  487808.0    NaN  558830.0    NaN
# 6   38239.0    NaN   44307.0    NaN   35500.0    NaN   30861.0    NaN
# 7   67149.0     Fc   57980.0     Fc   68237.0     Fc   67789.0     Fc
# 8  256771.0    NaN  256890.0    NaN  242243.0    NaN  209204.0    NaN
# 9    5174.0    NaN    5532.0    NaN    5784.0    NaN    5792.0    NaN

# %%
crops_africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9091 entries, 0 to 9090
# Columns: 125 entries, Area Code to Y2019F
# dtypes: float64(59), int64(3), object(63)
# memory usage: 8.7+ MB

# %% [markdown]
# ### Load all datasets

# %%
def open_all_datasets_df(item):
    df = pd.read_csv('https://raw.githubusercontent.com/nicoboou/ml_eml/main/data/agriculture-crop-production/Production_Crops_E_' + str(item) + '.csv', low_memory = False, encoding='latin1')
    df['Continent'] = item
    return df

# %%
continents = ['Africa','Americas','Asia','Europe','Oceania']

# %%
crops_raw = pd.DataFrame()

for continent in continents:
    crops_raw = crops_raw.append(open_all_datasets_df(continent))

# %%
crops_raw
# Out:
#       Area Code     Area  Item Code                     Item  Element Code  \
# 0             4  Algeria        221      Almonds, with shell          5312
# 1             4  Algeria        221      Almonds, with shell          5419
# 2             4  Algeria        221      Almonds, with shell          5510
# 3             4  Algeria        515                   Apples          5312
# 4             4  Algeria        515                   Apples          5419
# ...         ...      ...        ...                      ...           ...
# 1649        155  Vanuatu       1720  Roots and Tubers, Total          5419
# 1650        155  Vanuatu       1720  Roots and Tubers, Total          5510
# 1651        155  Vanuatu       1735       Vegetables Primary          5312
# 1652        155  Vanuatu       1735       Vegetables Primary          5419
# 1653        155  Vanuatu       1735       Vegetables Primary          5510
#
#              Element    Unit     Y1961 Y1961F     Y1962 Y1962F     Y1963  \
# 0     Area harvested      ha   13300.0      F   13300.0      F   13300.0
# 1              Yield   hg/ha    4511.0     Fc    4511.0     Fc    4511.0
# 2         Production  tonnes    6000.0    NaN    6000.0    NaN    6000.0
# 3     Area harvested      ha    3400.0      F    3100.0      F    2800.0
# 4              Yield   hg/ha   45294.0     Fc   45161.0     Fc   46429.0
# ...              ...     ...       ...    ...       ...    ...       ...
# 1649           Yield   hg/ha  225455.0     Fc  227273.0     Fc  229091.0
# 1650      Production  tonnes   24800.0      A   25000.0      A   25200.0
# 1651  Area harvested      ha     200.0      A     210.0      A     220.0
# 1652           Yield   hg/ha  150000.0     Fc  150000.0     Fc  150000.0
# 1653      Production  tonnes    3000.0      A    3150.0      A    3300.0
#
#      Y1963F     Y1964 Y1964F     Y1965 Y1965F     Y1966 Y1966F     Y1967  \
# 0         F   14200.0      F   13800.0      F   12700.0      F   12900.0
# 1        Fc    4507.0     Fc    4493.0     Fc    4488.0     Fc    4510.0
# 2       NaN    6400.0    NaN    6200.0    NaN    5700.0    NaN    5818.0
# 3         F    2700.0      F    2900.0      F    2500.0      F    2500.0
# 4        Fc   46078.0     Fc   45348.0     Fc   44832.0     Fc   45456.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc  220870.0     Fc  216949.0     Fc  216667.0     Fc  208800.0
# 1650      A   25400.0      A   25600.0      A   26000.0      A   26100.0
# 1651      A     230.0      A     240.0      A     250.0      A     260.0
# 1652     Fc  150000.0     Fc  150000.0     Fc  150000.0     Fc  150000.0
# 1653      A    3450.0      A    3600.0      A    3750.0      A    3900.0
#
#      Y1967F     Y1968 Y1968F     Y1969 Y1969F     Y1970 Y1970F     Y1971  \
# 0         F   10000.0      F    5500.0      F    6700.0      F    4600.0
# 1        Fc    4497.0     Fc    4484.0     Fc    4478.0     Fc    4500.0
# 2       NaN    4497.0    NaN    2466.0    NaN    3000.0    NaN    2070.0
# 3         F    2300.0      F    2600.0      F    2800.0      F    3000.0
# 4        Fc   45609.0     Fc   45681.0     Fc   46071.0     Fc   45020.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc  209375.0     Fc  207692.0     Fc  202222.0     Fc  196429.0
# 1650      A   26800.0      A   27000.0      A   27300.0      A   27500.0
# 1651      A     270.0      A     280.0      A     290.0      A     300.0
# 1652     Fc  150000.0     Fc  150000.0     Fc  151724.0     Fc  153333.0
# 1653      A    4050.0      A    4200.0      A    4400.0      A    4600.0
#
#      Y1971F     Y1972 Y1972F     Y1973 Y1973F     Y1974 Y1974F     Y1975  \
# 0         F    8300.0      F    9200.0      F   10150.0      F   11000.0
# 1        Fc    4514.0     Fc    4502.0     Fc    4500.0     Fc    4542.0
# 2       NaN    3747.0    NaN    4142.0    NaN    4567.0    NaN    4996.0
# 3         F    2500.0      F    2200.0      F    3200.0      F    4300.0
# 4        Fc   45920.0     Fc   45736.0     Fc   45525.0     Fc   50174.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc  198571.0     Fc  195862.0     Fc  196552.0     Fc  195270.0
# 1650      A   27800.0      A   28400.0      A   28500.0      A   28900.0
# 1651      A     320.0      A     330.0      A     345.0      A     360.0
# 1652     Fc  150000.0     Fc  151515.0     Fc  150725.0     Fc  150000.0
# 1653      A    4800.0      A    5000.0      A    5200.0      A    5400.0
#
#      Y1975F     Y1976 Y1976F     Y1977 Y1977F     Y1978 Y1978F     Y1979  \
# 0         F   18250.0      F   10400.0      F    7100.0      F    8100.0
# 1        Fc    4498.0     Fc    4487.0     Fc    4496.0     Fc    4483.0
# 2       NaN    8208.0    NaN    4666.0    NaN    3192.0    NaN    3631.0
# 3         F    3200.0      F    3800.0      F    3200.0      F    3000.0
# 4        Fc   45700.0     Fc   50471.0     Fc   48678.0     Fc   45520.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc  193333.0     Fc  200000.0     Fc  200000.0     Fc  200000.0
# 1650      A   29000.0      A   30000.0      A   30000.0      A   30000.0
# 1651      A     370.0      A     390.0      A     400.0      A     410.0
# 1652     Fc  151351.0     Fc  148718.0     Fc  150000.0     Fc  151220.0
# 1653      A    5600.0      A    5800.0      A    6000.0      A    6200.0
#
#      Y1979F     Y1980 Y1980F     Y1981 Y1981F     Y1982 Y1982F     Y1983  \
# 0         F    8700.0      F   15960.0    NaN   15450.0    NaN   18030.0
# 1        Fc    4483.0     Fc    4969.0     Fc    4296.0     Fc    3934.0
# 2       NaN    3900.0    NaN    7930.0    NaN    6637.0    NaN    7093.0
# 3         F    4300.0      F    4600.0      F    4900.0      F    4800.0
# 4        Fc   50740.0     Fc   50839.0     Fc   49951.0     Fc   49825.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc  200000.0     Fc  188889.0     Fc  194737.0     Fc  194872.0
# 1650      A   32000.0      A   34000.0      A   37000.0      A   38000.0
# 1651      A     425.0      A     430.0      A     445.0      A     450.0
# 1652     Fc  150588.0     Fc  151163.0     Fc  150562.0     Fc  151111.0
# 1653      A    6400.0      A    6500.0      A    6700.0      A    6800.0
#
#      Y1983F     Y1984 Y1984F     Y1985 Y1985F     Y1986 Y1986F     Y1987  \
# 0       NaN   16490.0    NaN   21100.0    NaN   20860.0    NaN   21000.0
# 1        Fc    4534.0     Fc    4716.0     Fc    3864.0     Fc    3930.0
# 2       NaN    7476.0    NaN    9951.0    NaN    8060.0    NaN    8253.0
# 3         F    7800.0      F    8000.0      F    8000.0      F    8700.0
# 4        Fc   49810.0     Fc   53000.0     Fc   50874.0     Fc   50216.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc  192213.0     Fc  130000.0     Fc  111429.0     Fc   86667.0
# 1650      A   39000.0      A   39000.0      A   39000.0      A   39000.0
# 1651      A     460.0      A     470.0      A     485.0      A     480.0
# 1652     Fc  150000.0     Fc  155319.0     Fc  156701.0     Fc  156250.0
# 1653      A    6900.0      A    7300.0      A    7600.0      A    7500.0
#
#      Y1987F     Y1988 Y1988F     Y1989 Y1989F     Y1990 Y1990F     Y1991  \
# 0       NaN   21370.0    NaN   23610.0    NaN   25010.0    NaN   24240.0
# 1        Fc    4528.0     Fc    5268.0     Fc    4691.0     Fc    6505.0
# 2       NaN    9676.0    NaN   12438.0    NaN   11733.0    NaN   15768.0
# 3         F    8000.0      F   10200.0      F   10740.0    NaN   10960.0
# 4        Fc   49975.0     Fc   50387.0     Fc   36258.0     Fc   43638.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   80851.0     Fc   80851.0     Fc   80412.0     Fc   76000.0
# 1650      A   38000.0      A   38000.0      A   39000.0      A   38000.0
# 1651      A     500.0      A     500.0      A     487.0      A     532.0
# 1652     Fc  152000.0     Fc  156000.0     Fc  164271.0     Fc  148496.0
# 1653      A    7600.0      A    7800.0      A    8000.0      A    7900.0
#
#      Y1991F     Y1992 Y1992F     Y1993 Y1993F     Y1994 Y1994F     Y1995  \
# 0       NaN   24970.0    NaN   25880.0    NaN   26130.0    NaN   24860.0
# 1        Fc    7169.0     Fc    9538.0     Fc    7312.0     Fc    7992.0
# 2       NaN   17901.0    NaN   24685.0    NaN   19106.0    NaN   19869.0
# 3       NaN   11140.0    NaN   12020.0    NaN   11800.0    NaN   11930.0
# 4        Fc   55641.0     Fc   52753.0     Fc   41777.0     Fc   53764.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   80000.0     Fc   79343.0     Fc   79326.0     Fc   79404.0
# 1650      A   36000.0      A   28000.0      A   32000.0      A   32000.0
# 1651      A     537.0      A     541.0      A     541.0      A     547.0
# 1652     Fc  148976.0     Fc  149409.0     Fc  149723.0     Fc  149909.0
# 1653      A    8000.0      A    8083.0      A    8100.0      A    8200.0
#
#      Y1995F     Y1996 Y1996F     Y1997 Y1997F     Y1998 Y1998F     Y1999  \
# 0       NaN   25190.0    NaN   27440.0    NaN   26490.0    NaN   26820.0
# 1        Fc   13323.0     Fc    7069.0     Fc    8169.0     Fc    9546.0
# 2       NaN   33561.0    NaN   19396.0    NaN   21641.0    NaN   25602.0
# 3       NaN   12190.0    NaN   12260.0    NaN   12870.0    NaN   13020.0
# 4        Fc   60598.0     Fc   53446.0     Fc   58574.0     Fc   67065.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   79484.0     Fc   79167.0     Fc   79614.0     Fc   79773.0
# 1650      A   37000.0      A   38000.0      A   38127.0      A   38578.0
# 1651      A     600.0      A     620.0      A     650.0      A     660.0
# 1652     Fc  150000.0     Fc  153226.0     Fc  150769.0     Fc  151515.0
# 1653      A    9000.0      A    9500.0      A    9800.0      A   10000.0
#
#      Y1999F     Y2000 Y2000F     Y2001 Y2001F     Y2002 Y2002F     Y2003  \
# 0       NaN   27150.0    NaN   26980.0    NaN   27720.0    NaN   30630.0
# 1        Fc    9754.0     Fc    9340.0     Fc   11648.0     Fc   10524.0
# 2       NaN   26483.0    NaN   25199.0    NaN   32287.0    NaN   32234.0
# 3       NaN   13480.0    NaN   14040.0    NaN   15240.0    NaN   18080.0
# 4        Fc   71600.0     Fc   74715.0     Fc   79421.0     Fc   74968.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   79592.0     Fc   81000.0     Fc   81161.0     Fc   81418.0
# 1650      A   39000.0      A   40500.0      A   41400.0      A   42500.0
# 1651      A     662.0      A     669.0      A     680.0      A     690.0
# 1652     Fc  153021.0     Fc  153961.0     Fc  155882.0     Fc  156522.0
# 1653      A   10130.0      A   10300.0      A   10600.0      A   10800.0
#
#      Y2003F     Y2004 Y2004F     Y2005 Y2005F     Y2006 Y2006F     Y2007  \
# 0       NaN   30453.0    NaN   35099.0    NaN   39098.0    NaN   40890.0
# 1        Fc   12473.0     Fc   12929.0     Fc   13728.0     Fc    8342.0
# 2       NaN   37985.0    NaN   45379.0    NaN   53673.0    NaN   34110.0
# 3       NaN   19861.0    NaN   24279.0    NaN   28658.0    NaN   31904.0
# 4        Fc   83265.0     Fc   82257.0     Fc   98835.0     Fc   59557.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   82692.0     Fc   81481.0     Fc   81818.0     Fc   81919.0
# 1650      A   43000.0      A   44000.0      A   45000.0      A   44646.0
# 1651      A     700.0      A     711.0      A     720.0      A     750.0
# 1652     Fc  157143.0     Fc  157103.0     Fc  157472.0     Fc  153333.0
# 1653      A   11000.0      A   11170.0      A   11338.0      A   11500.0
#
#      Y2007F     Y2008 Y2008F     Y2009 Y2009F     Y2010 Y2010F     Y2011  \
# 0       NaN   39787.0    NaN   39313.0    NaN   54485.0    NaN   52245.0
# 1        Fc    9933.0     Fc   12055.0     Fc   10457.0     Fc    9689.0
# 2       NaN   39521.0    NaN   47393.0    NaN   56973.0    NaN   50621.0
# 3       NaN   33206.0    NaN   36616.0    NaN   52419.0    NaN   51080.0
# 4        Fc   78590.0     Fc   73047.0     Fc   72233.0     Fc   79112.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   82727.0     Fc   82883.0     Fc   82072.0     Fc   80645.0
# 1650      A   45500.0      A   46000.0      A   47700.0      A   50000.0
# 1651      A     736.0      A     745.0      A     753.0      A     762.0
# 1652     Fc  158927.0     Fc  159664.0     Fc  160651.0     Fc  161444.0
# 1653      A   11697.0      A   11895.0      A   12097.0      A   12302.0
#
#      Y2011F     Y2012 Y2012F     Y2013 Y2013F     Y2014 Y2014F     Y2015  \
# 0       NaN   49975.0    NaN   49011.0    NaN   39050.0    NaN   40403.0
# 1        Fc   13304.0     Fc   12965.0     Fc   16601.0     Fc   18930.0
# 2       NaN   66487.0    NaN   63545.0    NaN   64827.0    NaN   76482.0
# 3       NaN   48828.0    NaN   48064.0    NaN   40418.0    NaN   41011.0
# 4        Fc   81414.0     Fc   94860.0     Fc  114507.0     Fc  110086.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   82258.0     Fc   82540.0     Fc   82518.0     Fc   82467.0
# 1650      A   51000.0      A   52000.0      A   52374.0      A   52251.0
# 1651      A     750.0      A     779.0      A     791.0      A     801.0
# 1652     Fc  166667.0     Fc  163248.0     Fc  163540.0     Fc  164819.0
# 1653      A   12500.0      A   12717.0      A   12936.0      A   13202.0
#
#      Y2015F     Y2016 Y2016F     Y2017 Y2017F     Y2018 Y2018F     Y2019  \
# 0       NaN   49983.0    NaN   50100.0    NaN   43043.0    NaN   35380.0
# 1        Fc   13223.0     Fc   12362.0     Fc   13292.0     Fc   20467.0
# 2       NaN   66095.0    NaN   61934.0    NaN   57213.0    NaN   72412.0
# 3       NaN   46070.0    NaN   44620.0    NaN   39034.0    NaN   32989.0
# 4        Fc  108716.0     Fc  110766.0     Fc  124970.0     Fc  169399.0
# ...     ...       ...    ...       ...    ...       ...    ...       ...
# 1649     Fc   82306.0     Fc   82341.0     Fc   82374.0     Fc   82407.0
# 1650      A   52314.0      A   52838.0      A   53362.0      A   53886.0
# 1651      A     804.0      A     810.0      A     817.0      A     824.0
# 1652     Fc  165547.0     Fc  166358.0     Fc  166952.0     Fc  167524.0
# 1653      A   13310.0      A   13475.0      A   13640.0      A   13804.0
#
#      Y2019F Continent
# 0       NaN    Africa
# 1        Fc    Africa
# 2       NaN    Africa
# 3       NaN    Africa
# 4        Fc    Africa
# ...     ...       ...
# 1649     Fc   Oceania
# 1650      A   Oceania
# 1651      A   Oceania
# 1652     Fc   Oceania
# 1653      A   Oceania
#
# [38146 rows x 126 columns]

# %% [markdown]
# It appears that columns representing the data per year come with an indicator "F", let's dig into it !

# %%
flags_df = pd.read_csv("https://raw.githubusercontent.com/nicoboou/ml_eml/main/data/agriculture-crop-production/flags.csv", encoding="latin1")
flags_df
# Out:
#    ï»¿"Flag"                                              Flags
# 0        NaN                                      Official data
# 1          *                                  Unofficial figure
# 2          A  Aggregate, may include official, semi-official...
# 3         Bk                                    Break in series
# 4          C                                         Calculated
# 5         Ce            Calculated data based on estimated data
# 6         Cv                           Calculated through value
# 7          E  Expert sources from FAO (including other divis...
# 8          F                                       FAO estimate
# 9         Fb                         Data obtained as a balance
# 10        Fc                                    Calculated data
# 11        Fd               estimates - discontinued time series
# 12        Fk   Calculated data on the basis of official figures
# 13        Fm                                  Manual Estimation
# 14         I  Country data reported by International Organiz...
# 15        Im           FAO data based on imputation methodology
# 16         M                                 Data not available
# 17       NaN                                     Not applicable
# 18        NR                                       Not reported
# 19        NV                                 Data not available
# 20        Od           Official data - discontinued time series
# 21         P                          Provisional official data
# 22         Q  Official data reported on FAO Questionnaires f...
# 23        Qm  Official data from questionnaires and/or natio...
# 24         R     Estimated data using trading partners database
# 25         S                                  Standardized data
# 26        SD                            Statistical Discrepancy
# 27         W  Data reported on country official publications...
# 28         X                     International reliable sources
# 29         Z  When the Fertilizer Utilization Account (FUA) ...

# %% [markdown]
# Each year column comes with another column, stating the source of the figures for this year (whether the figure was calculated with official data, estimated, etc).<br/>
# It is good info to know, but let's put these data pieces aside and keep a smaller df:

# %%
crops_all = copy.deepcopy(crops_raw)
crops_all = crops_all.loc[:, ~crops_all.columns.str.endswith('F')]
crops_all = crops_all[crops_all.columns[~crops_all.columns.str.endswith('F')]]
first_col = crops_all.pop('Continent')
crops_all.insert(0, 'Continent', first_col)
crops_all
# Out:
#      Continent  Area Code     Area  Item Code                     Item  \
# 0       Africa          4  Algeria        221      Almonds, with shell
# 1       Africa          4  Algeria        221      Almonds, with shell
# 2       Africa          4  Algeria        221      Almonds, with shell
# 3       Africa          4  Algeria        515                   Apples
# 4       Africa          4  Algeria        515                   Apples
# ...        ...        ...      ...        ...                      ...
# 1649   Oceania        155  Vanuatu       1720  Roots and Tubers, Total
# 1650   Oceania        155  Vanuatu       1720  Roots and Tubers, Total
# 1651   Oceania        155  Vanuatu       1735       Vegetables Primary
# 1652   Oceania        155  Vanuatu       1735       Vegetables Primary
# 1653   Oceania        155  Vanuatu       1735       Vegetables Primary
#
#       Element Code         Element    Unit     Y1961     Y1962     Y1963  \
# 0             5312  Area harvested      ha   13300.0   13300.0   13300.0
# 1             5419           Yield   hg/ha    4511.0    4511.0    4511.0
# 2             5510      Production  tonnes    6000.0    6000.0    6000.0
# 3             5312  Area harvested      ha    3400.0    3100.0    2800.0
# 4             5419           Yield   hg/ha   45294.0   45161.0   46429.0
# ...            ...             ...     ...       ...       ...       ...
# 1649          5419           Yield   hg/ha  225455.0  227273.0  229091.0
# 1650          5510      Production  tonnes   24800.0   25000.0   25200.0
# 1651          5312  Area harvested      ha     200.0     210.0     220.0
# 1652          5419           Yield   hg/ha  150000.0  150000.0  150000.0
# 1653          5510      Production  tonnes    3000.0    3150.0    3300.0
#
#          Y1964     Y1965     Y1966     Y1967     Y1968     Y1969     Y1970  \
# 0      14200.0   13800.0   12700.0   12900.0   10000.0    5500.0    6700.0
# 1       4507.0    4493.0    4488.0    4510.0    4497.0    4484.0    4478.0
# 2       6400.0    6200.0    5700.0    5818.0    4497.0    2466.0    3000.0
# 3       2700.0    2900.0    2500.0    2500.0    2300.0    2600.0    2800.0
# 4      46078.0   45348.0   44832.0   45456.0   45609.0   45681.0   46071.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649  220870.0  216949.0  216667.0  208800.0  209375.0  207692.0  202222.0
# 1650   25400.0   25600.0   26000.0   26100.0   26800.0   27000.0   27300.0
# 1651     230.0     240.0     250.0     260.0     270.0     280.0     290.0
# 1652  150000.0  150000.0  150000.0  150000.0  150000.0  150000.0  151724.0
# 1653    3450.0    3600.0    3750.0    3900.0    4050.0    4200.0    4400.0
#
#          Y1971     Y1972     Y1973     Y1974     Y1975     Y1976     Y1977  \
# 0       4600.0    8300.0    9200.0   10150.0   11000.0   18250.0   10400.0
# 1       4500.0    4514.0    4502.0    4500.0    4542.0    4498.0    4487.0
# 2       2070.0    3747.0    4142.0    4567.0    4996.0    8208.0    4666.0
# 3       3000.0    2500.0    2200.0    3200.0    4300.0    3200.0    3800.0
# 4      45020.0   45920.0   45736.0   45525.0   50174.0   45700.0   50471.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649  196429.0  198571.0  195862.0  196552.0  195270.0  193333.0  200000.0
# 1650   27500.0   27800.0   28400.0   28500.0   28900.0   29000.0   30000.0
# 1651     300.0     320.0     330.0     345.0     360.0     370.0     390.0
# 1652  153333.0  150000.0  151515.0  150725.0  150000.0  151351.0  148718.0
# 1653    4600.0    4800.0    5000.0    5200.0    5400.0    5600.0    5800.0
#
#          Y1978     Y1979     Y1980     Y1981     Y1982     Y1983     Y1984  \
# 0       7100.0    8100.0    8700.0   15960.0   15450.0   18030.0   16490.0
# 1       4496.0    4483.0    4483.0    4969.0    4296.0    3934.0    4534.0
# 2       3192.0    3631.0    3900.0    7930.0    6637.0    7093.0    7476.0
# 3       3200.0    3000.0    4300.0    4600.0    4900.0    4800.0    7800.0
# 4      48678.0   45520.0   50740.0   50839.0   49951.0   49825.0   49810.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649  200000.0  200000.0  200000.0  188889.0  194737.0  194872.0  192213.0
# 1650   30000.0   30000.0   32000.0   34000.0   37000.0   38000.0   39000.0
# 1651     400.0     410.0     425.0     430.0     445.0     450.0     460.0
# 1652  150000.0  151220.0  150588.0  151163.0  150562.0  151111.0  150000.0
# 1653    6000.0    6200.0    6400.0    6500.0    6700.0    6800.0    6900.0
#
#          Y1985     Y1986     Y1987     Y1988     Y1989     Y1990     Y1991  \
# 0      21100.0   20860.0   21000.0   21370.0   23610.0   25010.0   24240.0
# 1       4716.0    3864.0    3930.0    4528.0    5268.0    4691.0    6505.0
# 2       9951.0    8060.0    8253.0    9676.0   12438.0   11733.0   15768.0
# 3       8000.0    8000.0    8700.0    8000.0   10200.0   10740.0   10960.0
# 4      53000.0   50874.0   50216.0   49975.0   50387.0   36258.0   43638.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649  130000.0  111429.0   86667.0   80851.0   80851.0   80412.0   76000.0
# 1650   39000.0   39000.0   39000.0   38000.0   38000.0   39000.0   38000.0
# 1651     470.0     485.0     480.0     500.0     500.0     487.0     532.0
# 1652  155319.0  156701.0  156250.0  152000.0  156000.0  164271.0  148496.0
# 1653    7300.0    7600.0    7500.0    7600.0    7800.0    8000.0    7900.0
#
#          Y1992     Y1993     Y1994     Y1995     Y1996     Y1997     Y1998  \
# 0      24970.0   25880.0   26130.0   24860.0   25190.0   27440.0   26490.0
# 1       7169.0    9538.0    7312.0    7992.0   13323.0    7069.0    8169.0
# 2      17901.0   24685.0   19106.0   19869.0   33561.0   19396.0   21641.0
# 3      11140.0   12020.0   11800.0   11930.0   12190.0   12260.0   12870.0
# 4      55641.0   52753.0   41777.0   53764.0   60598.0   53446.0   58574.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649   80000.0   79343.0   79326.0   79404.0   79484.0   79167.0   79614.0
# 1650   36000.0   28000.0   32000.0   32000.0   37000.0   38000.0   38127.0
# 1651     537.0     541.0     541.0     547.0     600.0     620.0     650.0
# 1652  148976.0  149409.0  149723.0  149909.0  150000.0  153226.0  150769.0
# 1653    8000.0    8083.0    8100.0    8200.0    9000.0    9500.0    9800.0
#
#          Y1999     Y2000     Y2001     Y2002     Y2003     Y2004     Y2005  \
# 0      26820.0   27150.0   26980.0   27720.0   30630.0   30453.0   35099.0
# 1       9546.0    9754.0    9340.0   11648.0   10524.0   12473.0   12929.0
# 2      25602.0   26483.0   25199.0   32287.0   32234.0   37985.0   45379.0
# 3      13020.0   13480.0   14040.0   15240.0   18080.0   19861.0   24279.0
# 4      67065.0   71600.0   74715.0   79421.0   74968.0   83265.0   82257.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649   79773.0   79592.0   81000.0   81161.0   81418.0   82692.0   81481.0
# 1650   38578.0   39000.0   40500.0   41400.0   42500.0   43000.0   44000.0
# 1651     660.0     662.0     669.0     680.0     690.0     700.0     711.0
# 1652  151515.0  153021.0  153961.0  155882.0  156522.0  157143.0  157103.0
# 1653   10000.0   10130.0   10300.0   10600.0   10800.0   11000.0   11170.0
#
#          Y2006     Y2007     Y2008     Y2009     Y2010     Y2011     Y2012  \
# 0      39098.0   40890.0   39787.0   39313.0   54485.0   52245.0   49975.0
# 1      13728.0    8342.0    9933.0   12055.0   10457.0    9689.0   13304.0
# 2      53673.0   34110.0   39521.0   47393.0   56973.0   50621.0   66487.0
# 3      28658.0   31904.0   33206.0   36616.0   52419.0   51080.0   48828.0
# 4      98835.0   59557.0   78590.0   73047.0   72233.0   79112.0   81414.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649   81818.0   81919.0   82727.0   82883.0   82072.0   80645.0   82258.0
# 1650   45000.0   44646.0   45500.0   46000.0   47700.0   50000.0   51000.0
# 1651     720.0     750.0     736.0     745.0     753.0     762.0     750.0
# 1652  157472.0  153333.0  158927.0  159664.0  160651.0  161444.0  166667.0
# 1653   11338.0   11500.0   11697.0   11895.0   12097.0   12302.0   12500.0
#
#          Y2013     Y2014     Y2015     Y2016     Y2017     Y2018     Y2019
# 0      49011.0   39050.0   40403.0   49983.0   50100.0   43043.0   35380.0
# 1      12965.0   16601.0   18930.0   13223.0   12362.0   13292.0   20467.0
# 2      63545.0   64827.0   76482.0   66095.0   61934.0   57213.0   72412.0
# 3      48064.0   40418.0   41011.0   46070.0   44620.0   39034.0   32989.0
# 4      94860.0  114507.0  110086.0  108716.0  110766.0  124970.0  169399.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 1649   82540.0   82518.0   82467.0   82306.0   82341.0   82374.0   82407.0
# 1650   52000.0   52374.0   52251.0   52314.0   52838.0   53362.0   53886.0
# 1651     779.0     791.0     801.0     804.0     810.0     817.0     824.0
# 1652  163248.0  163540.0  164819.0  165547.0  166358.0  166952.0  167524.0
# 1653   12717.0   12936.0   13202.0   13310.0   13475.0   13640.0   13804.0
#
# [38146 rows x 67 columns]

# %% [markdown]
# ## 2. Loading the *Gas Emissions* dataset

# %%
# Loading Gas Emissions' dataset

url = 'https://raw.githubusercontent.com/nicoboou/ml_eml/main/data/emissions/emissions_full.csv'
emissions_df = pd.read_csv(url, sep=',',encoding='latin-1',low_memory=False)
emissions_df
# Out:
#        Code zone         Zone  Code Produit  \
# 0              2  Afghanistan          5058
# 1              2  Afghanistan          5058
# 2              2  Afghanistan          5058
# 3              2  Afghanistan          5058
# 4              2  Afghanistan          5058
# ...          ...          ...           ...
# 35751       5873         OECD          6516
# 35752       5873         OECD          6516
# 35753       5873         OECD          6516
# 35754       5873         OECD          6516
# 35755       5873         OECD          6516
#
#                                    Produit  Code Élément  \
# 0                   Fermentation entérique          7225
# 1                   Fermentation entérique          7225
# 2                   Fermentation entérique        724413
# 3                   Fermentation entérique        724413
# 4                   Fermentation entérique        723113
# ...                                    ...           ...
# 35751  Changement d'utilisation des terres          7230
# 35752  Changement d'utilisation des terres          7273
# 35753  Changement d'utilisation des terres        724413
# 35754  Changement d'utilisation des terres        724313
# 35755  Changement d'utilisation des terres        723113
#
#                                      Élément  Code source      Source  \
# 0                            Émissions (CH4)         3050  FAO TIER 1
# 1                            Émissions (CH4)         3051      UNFCCC
# 2      Émissions (CO2eq) venant de CH4 (AR5)         3050  FAO TIER 1
# 3      Émissions (CO2eq) venant de CH4 (AR5)         3051      UNFCCC
# 4                    Émissions (CO2eq) (AR5)         3050  FAO TIER 1
# ...                                      ...          ...         ...
# 35751                        Émissions (N2O)         3050  FAO TIER 1
# 35752                        Émissions (CO2)         3050  FAO TIER 1
# 35753  Émissions (CO2eq) venant de CH4 (AR5)         3050  FAO TIER 1
# 35754  Émissions (CO2eq) venant de N2O (AR5)         3050  FAO TIER 1
# 35755                Émissions (CO2eq) (AR5)         3050  FAO TIER 1
#
#             Unité      Y1961 Y1961F  Y1961N      Y1962 Y1962F  Y1962N  \
# 0      kilotonnes   240.6831     Fc     NaN   245.3106     Fc     NaN
# 1      kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
# 2      kilotonnes  6739.1279     Fc     NaN  6868.6971     Fc     NaN
# 3      kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
# 4      kilotonnes  6739.1279     Fc     NaN  6868.6971     Fc     NaN
# ...           ...        ...    ...     ...        ...    ...     ...
# 35751  kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
# 35752  kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
# 35753  kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
# 35754  kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
# 35755  kilotonnes        NaN    NaN     NaN        NaN    NaN     NaN
#
#            Y1963 Y1963F  Y1963N     Y1964 Y1964F  Y1964N     Y1965 Y1965F  \
# 0       255.8285     Fc     NaN   259.065     Fc     NaN   265.598     Fc
# 1            NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 2      7163.1986     Fc     NaN  7253.820     Fc     NaN  7436.744     Fc
# 3            NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 4      7163.1986     Fc     NaN  7253.820     Fc     NaN  7436.744     Fc
# ...          ...    ...     ...       ...    ...     ...       ...    ...
# 35751        NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35752        NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35753        NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35754        NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35755        NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
#
#        Y1965N     Y1966 Y1966F  Y1966N     Y1967 Y1967F  Y1967N      Y1968  \
# 0         NaN   276.994     Fc     NaN   280.094     Fc     NaN   288.8210
# 1         NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
# 2         NaN  7755.832     Fc     NaN  7842.632     Fc     NaN  8086.9891
# 3         NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
# 4         NaN  7755.832     Fc     NaN  7842.632     Fc     NaN  8086.9891
# ...       ...       ...    ...     ...       ...    ...     ...        ...
# 35751     NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
# 35752     NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
# 35753     NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
# 35754     NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
# 35755     NaN       NaN    NaN     NaN       NaN    NaN     NaN        NaN
#
#       Y1968F  Y1968N     Y1969 Y1969F  Y1969N    Y1970 Y1970F  Y1970N  \
# 0         Fc     NaN   286.382     Fc     NaN   290.26     Fc     NaN
# 1        NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
# 2         Fc     NaN  8018.696     Fc     NaN  8127.28     Fc     NaN
# 3        NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
# 4         Fc     NaN  8018.696     Fc     NaN  8127.28     Fc     NaN
# ...      ...     ...       ...    ...     ...      ...    ...     ...
# 35751    NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
# 35752    NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
# 35753    NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
# 35754    NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
# 35755    NaN     NaN       NaN    NaN     NaN      NaN    NaN     NaN
#
#          Y1971 Y1971F  Y1971N     Y1972 Y1972F  Y1972N     Y1973 Y1973F  \
# 0       287.79     Fc     NaN   231.527     Fc     NaN   244.979     Fc
# 1          NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 2      8058.12     Fc     NaN  6482.756     Fc     NaN  6859.412     Fc
# 3          NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 4      8058.12     Fc     NaN  6482.756     Fc     NaN  6859.412     Fc
# ...        ...    ...     ...       ...    ...     ...       ...    ...
# 35751      NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35752      NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35753      NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35754      NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
# 35755      NaN    NaN     NaN       NaN    NaN     NaN       NaN    NaN
#
#        Y1973N     Y1974 Y1974F  Y1974N      Y1975 Y1975F  Y1975N     Y1976  \
# 0         NaN   262.836     Fc     NaN   282.0740     Fc     NaN   288.225
# 1         NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
# 2         NaN  7359.408     Fc     NaN  7898.0731     Fc     NaN  8070.300
# 3         NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
# 4         NaN  7359.408     Fc     NaN  7898.0731     Fc     NaN  8070.300
# ...       ...       ...    ...     ...        ...    ...     ...       ...
# 35751     NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
# 35752     NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
# 35753     NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
# 35754     NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
# 35755     NaN       NaN    NaN     NaN        NaN    NaN     NaN       NaN
#
#       Y1976F  Y1976N     Y1977 Y1977F  Y1977N      Y1978 Y1978F  Y1978N  \
# 0         Fc     NaN   280.876     Fc     NaN   280.2850     Fc     NaN
# 1        NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
# 2         Fc     NaN  7864.528     Fc     NaN  7847.9811     Fc     NaN
# 3        NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
# 4         Fc     NaN  7864.528     Fc     NaN  7847.9811     Fc     NaN
# ...      ...     ...       ...    ...     ...        ...    ...     ...
# 35751    NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
# 35752    NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
# 35753    NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
# 35754    NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
# 35755    NaN     NaN       NaN    NaN     NaN        NaN    NaN     NaN
#
#           Y1979 Y1979F  Y1979N    Y1980 Y1980F  Y1980N    Y1981 Y1981F  \
# 0       274.235     Fc     NaN   275.37     Fc     NaN   278.21     Fc
# 1           NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 2      7678.580     Fc     NaN  7710.36     Fc     NaN  7789.88     Fc
# 3           NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 4      7678.580     Fc     NaN  7710.36     Fc     NaN  7789.88     Fc
# ...         ...    ...     ...      ...    ...     ...      ...    ...
# 35751       NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35752       NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35753       NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35754       NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35755       NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
#
#        Y1981N    Y1982 Y1982F  Y1982N    Y1983 Y1983F  Y1983N    Y1984 Y1984F  \
# 0         NaN   277.94     Fc     NaN   262.63     Fc     NaN   230.15     Fc
# 1         NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 2         NaN  7782.32     Fc     NaN  7353.64     Fc     NaN  6444.20     Fc
# 3         NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 4         NaN  7782.32     Fc     NaN  7353.64     Fc     NaN  6444.20     Fc
# ...       ...      ...    ...     ...      ...    ...     ...      ...    ...
# 35751     NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35752     NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35753     NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35754     NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
# 35755     NaN      NaN    NaN     NaN      NaN    NaN     NaN      NaN    NaN
#
#        Y1984N    Y1985 Y1985F  Y1985N     Y1986 Y1986F  Y1986N    Y1987  \
# 0         NaN   202.73     Fc     NaN   160.264     Fc     NaN   172.94
# 1         NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
# 2         NaN  5676.44     Fc     NaN  4487.392     Fc     NaN  4842.32
# 3         NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
# 4         NaN  5676.44     Fc     NaN  4487.392     Fc     NaN  4842.32
# ...       ...      ...    ...     ...       ...    ...     ...      ...
# 35751     NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
# 35752     NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
# 35753     NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
# 35754     NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
# 35755     NaN      NaN    NaN     NaN       NaN    NaN     NaN      NaN
#
#       Y1987F  Y1987N     Y1988 Y1988F  Y1988N     Y1989 Y1989F  Y1989N  \
# 0         Fc     NaN   181.436     Fc     NaN   179.562     Fc     NaN
# 1        NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
# 2         Fc     NaN  5080.208     Fc     NaN  5027.736     Fc     NaN
# 3        NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
# 4         Fc     NaN  5080.208     Fc     NaN  5027.736     Fc     NaN
# ...      ...     ...       ...    ...     ...       ...    ...     ...
# 35751    NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
# 35752    NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
# 35753    NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
# 35754    NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
# 35755    NaN     NaN       NaN    NaN     NaN       NaN    NaN     NaN
#
#              Y1990 Y1990F Y1990N        Y1991 Y1991F Y1991N        Y1992  \
# 0         178.4682     Fc    NaN     187.5500     Fc    NaN     189.7600
# 1              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 2        4997.1108     Fc    NaN    5251.4000     Fc    NaN    5313.2800
# 3              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 4        4997.1108     Fc    NaN    5251.4000     Fc    NaN    5313.2800
# ...            ...    ...    ...          ...    ...    ...          ...
# 35751       1.4119     Fc    NaN       1.4119     Fc    NaN       1.4119
# 35752  306473.8942     Fc    NaN  306473.8942     Fc    NaN  306473.8942
# 35753     768.5391     Fc    NaN     768.5391     Fc    NaN     768.5391
# 35754     374.1567     Fc    NaN     374.1567     Fc    NaN     374.1567
# 35755  307616.5900     Fc    NaN  307616.5900     Fc    NaN  307616.5900
#
#       Y1992F Y1992N        Y1993 Y1993F Y1993N        Y1994 Y1994F Y1994N  \
# 0         Fc    NaN     190.8300     Fc    NaN     197.9210     Fc    NaN
# 1        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 2         Fc    NaN    5343.2400     Fc    NaN    5541.7880     Fc    NaN
# 3        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 4         Fc    NaN    5343.2400     Fc    NaN    5541.7880     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35751     Fc    NaN       1.4119     Fc    NaN       1.4119     Fc    NaN
# 35752     Fc    NaN  307152.8342     Fc    NaN  307152.8342     Fc    NaN
# 35753     Fc    NaN     768.5391     Fc    NaN     768.5391     Fc    NaN
# 35754     Fc    NaN     374.1567     Fc    NaN     374.1567     Fc    NaN
# 35755     Fc    NaN  308295.5300     Fc    NaN  308295.5300     Fc    NaN
#
#              Y1995 Y1995F Y1995N        Y1996 Y1996F Y1996N        Y1997  \
# 0         211.1555     Fc    NaN     239.7213     Fc    NaN     264.6095
# 1              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 2        5912.3546     Fc    NaN    6712.1964     Fc    NaN    7409.0660
# 3              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 4        5912.3546     Fc    NaN    6712.1964     Fc    NaN    7409.0660
# ...            ...    ...    ...          ...    ...    ...          ...
# 35751       1.4119     Fc    NaN       1.3039     Fc    NaN       1.3187
# 35752  307152.8342     Fc    NaN  307152.8342     Fc    NaN  307152.8342
# 35753     768.5391     Fc    NaN    1241.2907     Fc    NaN    1255.3795
# 35754     374.1567     Fc    NaN     345.5274     Fc    NaN     349.4491
# 35755  308295.5300     Fc    NaN  308739.6523     Fc    NaN  308757.6628
#
#       Y1997F Y1997N        Y1998 Y1998F Y1998N        Y1999 Y1999F Y1999N  \
# 0         Fc    NaN     283.4502     Fc    NaN     318.3395     Fc    NaN
# 1        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 2         Fc    NaN    7936.6067     Fc    NaN    8913.5049     Fc    NaN
# 3        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 4         Fc    NaN    7936.6067     Fc    NaN    8913.5049     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35751     Fc    NaN       5.3475     Fc    NaN       2.3702     Fc    NaN
# 35752     Fc    NaN  307152.8342     Fc    NaN  307152.8342     Fc    NaN
# 35753     Fc    NaN    5090.8276     Fc    NaN    2256.4465     Fc    NaN
# 35754     Fc    NaN    1417.0894     Fc    NaN     628.1075     Fc    NaN
# 35755     Fc    NaN  313660.7512     Fc    NaN  310037.3882     Fc    NaN
#
#              Y2000 Y2000F Y2000N        Y2001 Y2001F Y2001N        Y2002  \
# 0         272.1400     Fc    NaN     225.4030     Fc    NaN     287.8930
# 1              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 2        7619.9200     Fc    NaN    6311.2840     Fc    NaN    8061.0040
# 3              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 4        7619.9200     Fc    NaN    6311.2840     Fc    NaN    8061.0040
# ...            ...    ...    ...          ...    ...    ...          ...
# 35751       2.1013     Fc    NaN       0.3632     Fc    NaN       1.4735
# 35752  307152.8342     Fc    NaN  260435.8387     Fc    NaN  260435.8387
# 35753    2000.4147     Fc    NaN     111.3891     Fc    NaN     451.8678
# 35754     556.8381     Fc    NaN      96.2547     Fc    NaN     390.4728
# 35755  309710.0871     Fc    NaN  260643.4824     Fc    NaN  261278.1793
#
#       Y2002F Y2002N        Y2003 Y2003F Y2003N        Y2004 Y2004F Y2004N  \
# 0         Fc    NaN     293.6260     Fc    NaN     285.5980     Fc    NaN
# 1        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 2         Fc    NaN    8221.5280     Fc    NaN    7996.7440     Fc    NaN
# 3        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 4         Fc    NaN    8221.5280     Fc    NaN    7996.7440     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35751     Fc    NaN       3.8694     Fc    NaN       0.3919     Fc    NaN
# 35752     Fc    NaN  260435.8387     Fc    NaN  260435.8387     Fc    NaN
# 35753     Fc    NaN    1186.6022     Fc    NaN     120.1706     Fc    NaN
# 35754     Fc    NaN    1025.3791     Fc    NaN     103.8431     Fc    NaN
# 35755     Fc    NaN  262647.8200     Fc    NaN  260659.8524     Fc    NaN
#
#              Y2005 Y2005F Y2005N        Y2006 Y2006F Y2006N        Y2007  \
# 0         295.4010     Fc    NaN     300.8070     Fc    NaN     304.2250
# 1         309.0300    NaN    NaN          NaN    NaN    NaN          NaN
# 2        8271.2280     Fc    NaN    8422.5960     Fc    NaN    8518.3000
# 3        8652.8400    NaN    NaN          NaN    NaN    NaN          NaN
# 4        8271.2280     Fc    NaN    8422.5960     Fc    NaN    8518.3000
# ...            ...    ...    ...          ...    ...    ...          ...
# 35751       1.4179     Fc    NaN       1.4010     Fc    NaN       0.5689
# 35752  260435.8387     Fc    NaN  260435.8387     Fc    NaN  260435.8387
# 35753     434.8379     Fc    NaN     429.6424     Fc    NaN     174.4772
# 35754     375.7566     Fc    NaN     371.2671     Fc    NaN     150.7710
# 35755  261246.4332     Fc    NaN  261236.7482     Fc    NaN  260761.0869
#
#       Y2007F Y2007N        Y2008 Y2008F Y2008N        Y2009 Y2009F Y2009N  \
# 0         Fc    NaN     339.5590     Fc    NaN     345.6580     Fc    NaN
# 1        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 2         Fc    NaN    9507.6520     Fc    NaN    9678.4240     Fc    NaN
# 3        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 4         Fc    NaN    9507.6520     Fc    NaN    9678.4240     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35751     Fc    NaN       0.9682     Fc    NaN       1.4894     Fc    NaN
# 35752     Fc    NaN  260435.8387     Fc    NaN  260435.8387     Fc    NaN
# 35753     Fc    NaN     296.9212     Fc    NaN     456.7428     Fc    NaN
# 35754     Fc    NaN     256.5786     Fc    NaN     394.6854     Fc    NaN
# 35755     Fc    NaN  260989.3385     Fc    NaN  261287.2669     Fc    NaN
#
#              Y2010 Y2010F Y2010N        Y2011 Y2011F Y2011N        Y2012  \
# 0         401.0680     Fc    NaN     402.5130     Fc    NaN     396.9210
# 1              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 2       11229.9040     Fc    NaN   11270.3640     Fc    NaN   11113.7880
# 3              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 4       11229.9040     Fc    NaN   11270.3640     Fc    NaN   11113.7880
# ...            ...    ...    ...          ...    ...    ...          ...
# 35751       0.3298     Fc    NaN       1.8699     Fc    NaN       0.5001
# 35752  260435.8387     Fc    NaN  159202.3883     Fc    NaN  159202.3883
# 35753     101.1322     Fc    NaN     573.4284     Fc    NaN     153.3618
# 35754      87.3914     Fc    NaN     495.5169     Fc    NaN     132.5246
# 35755  260624.3623     Fc    NaN  160271.3336     Fc    NaN  159488.2747
#
#       Y2012F Y2012N        Y2013 Y2013F Y2013N        Y2014 Y2014F Y2014N  \
# 0         Fc    NaN     393.0930     Fc    NaN     398.2870     Fc    NaN
# 1        NaN    NaN     414.0000    NaN    NaN          NaN    NaN    NaN
# 2         Fc    NaN   11006.6040     Fc    NaN   11152.0360     Fc    NaN
# 3        NaN    NaN   11592.0000    NaN    NaN          NaN    NaN    NaN
# 4         Fc    NaN   11006.6040     Fc    NaN   11152.0360     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35751     Fc    NaN       1.4242     Fc    NaN       0.4180     Fc    NaN
# 35752     Fc    NaN  159202.3883     Fc    NaN  159202.3883     Fc    NaN
# 35753     Fc    NaN     436.7699     Fc    NaN     128.1795     Fc    NaN
# 35754     Fc    NaN     377.4261     Fc    NaN     110.7638     Fc    NaN
# 35755     Fc    NaN  160016.5843     Fc    NaN  159441.3315     Fc    NaN
#
#              Y2015 Y2015F Y2015N        Y2016 Y2016F Y2016N        Y2017  \
# 0         383.3023     Fc    NaN     380.8767     Fc    NaN     371.2863
# 1              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 2       10732.4631     Fc    NaN   10664.5483     Fc    NaN   10396.0163
# 3              NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 4       10732.4631     Fc    NaN   10664.5483     Fc    NaN   10396.0163
# ...            ...    ...    ...          ...    ...    ...          ...
# 35751       1.2957     Fc    NaN       0.8834     Fc    NaN       0.7522
# 35752  159202.3883     Fc    NaN  209078.1221     Fc    NaN  209078.1221
# 35753     397.3500     Fc    NaN     270.9106     Fc    NaN     230.6636
# 35754     343.3623     Fc    NaN     234.1021     Fc    NaN     199.3235
# 35755  159943.1006     Fc    NaN  209583.1348     Fc    NaN  209508.1091
#
#       Y2017F Y2017N        Y2018 Y2018F Y2018N        Y2019 Y2019F Y2019N  \
# 0         Fc    NaN     378.8870     Fc    NaN     389.6563     Fc    NaN
# 1        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 2         Fc    NaN   10608.8357     Fc    NaN   10910.3754     Fc    NaN
# 3        NaN    NaN          NaN    NaN    NaN          NaN    NaN    NaN
# 4         Fc    NaN   10608.8357     Fc    NaN   10910.3754     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35751     Fc    NaN       0.9253     Fc    NaN       1.0574     Fc    NaN
# 35752     Fc    NaN  209078.1221     Fc    NaN  209078.1221     Fc    NaN
# 35753     Fc    NaN     283.7454     Fc    NaN     324.2807     Fc    NaN
# 35754     Fc    NaN     245.1931     Fc    NaN     280.2209     Fc    NaN
# 35755     Fc    NaN  209607.0606     Fc    NaN  209682.6237     Fc    NaN
#
#        Y2020 Y2020F  Y2020N       Y2030 Y2030F  Y2030N       Y2050 Y2050F  \
# 0        NaN    NaN     NaN    453.7474     Fc     NaN    603.6185     Fc
# 1        NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
# 2        NaN    NaN     NaN  12704.9283     Fc     NaN  16901.3173     Fc
# 3        NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
# 4        NaN    NaN     NaN  12704.9283     Fc     NaN  16901.3173     Fc
# ...      ...    ...     ...         ...    ...     ...         ...    ...
# 35751    NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
# 35752    NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
# 35753    NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
# 35754    NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
# 35755    NaN    NaN     NaN         NaN    NaN     NaN         NaN    NaN
#
#        Y2050N
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 35751     NaN
# 35752     NaN
# 35753     NaN
# 35754     NaN
# 35755     NaN
#
# [35756 rows x 195 columns]

# %% [markdown]
# **Let's focus for now on CO2 emissions**

# %%
co2_df = emissions_df.drop(emissions_df[emissions_df['Code Élément'] != 7273].index)
co2_df
# Out:
#        Code zone         Zone  Code Produit  \
# 47             2  Afghanistan          6750
# 49             2  Afghanistan          6751
# 67             2  Afghanistan          6993
# 72             2  Afghanistan          6994
# 100            2  Afghanistan          1707
# ...          ...          ...           ...
# 35722       5873         OECD          1707
# 35730       5873         OECD          6824
# 35738       5873         OECD          6995
# 35746       5873         OECD          6996
# 35752       5873         OECD          6516
#
#                                    Produit  Code Élément          Élément  \
# 47               Conversion nette de forêt          7273  Émissions (CO2)
# 49                      Terres forestières          7273  Émissions (CO2)
# 67                      Feux de tourbières          7273  Émissions (CO2)
# 72                      On-farm energy use          7273  Émissions (CO2)
# 100                                 UTCATF          7273  Émissions (CO2)
# ...                                    ...           ...              ...
# 35722                               UTCATF          7273  Émissions (CO2)
# 35730                                AFOLU          7273  Émissions (CO2)
# 35738   Émissions sur les terres agricoles          7273  Émissions (CO2)
# 35746                  Farm-gate emissions          7273  Émissions (CO2)
# 35752  Changement d'utilisation des terres          7273  Émissions (CO2)
#
#        Code source      Source       Unité  Y1961 Y1961F  Y1961N  Y1962  \
# 47            3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 49            3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 67            3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 72            3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 100           3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# ...            ...         ...         ...    ...    ...     ...    ...
# 35722         3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 35730         3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 35738         3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 35746         3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
# 35752         3050  FAO TIER 1  kilotonnes    NaN    NaN     NaN    NaN
#
#       Y1962F  Y1962N  Y1963 Y1963F  Y1963N  Y1964 Y1964F  Y1964N  Y1965  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1965F  Y1965N  Y1966 Y1966F  Y1966N  Y1967 Y1967F  Y1967N  Y1968  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1968F  Y1968N  Y1969 Y1969F  Y1969N  Y1970 Y1970F  Y1970N  Y1971  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1971F  Y1971N  Y1972 Y1972F  Y1972N  Y1973 Y1973F  Y1973N  Y1974  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1974F  Y1974N  Y1975 Y1975F  Y1975N  Y1976 Y1976F  Y1976N  Y1977  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1977F  Y1977N  Y1978 Y1978F  Y1978N  Y1979 Y1979F  Y1979N  Y1980  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1980F  Y1980N  Y1981 Y1981F  Y1981N  Y1982 Y1982F  Y1982N  Y1983  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1983F  Y1983N  Y1984 Y1984F  Y1984N  Y1985 Y1985F  Y1985N  Y1986  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1986F  Y1986N  Y1987 Y1987F  Y1987N  Y1988 Y1988F  Y1988N  Y1989  \
# 47       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 49       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 67       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 72       NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 100      NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# ...      ...     ...    ...    ...     ...    ...    ...     ...    ...
# 35722    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35730    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35738    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35746    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
# 35752    NaN     NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN
#
#       Y1989F  Y1989N        Y1990 Y1990F Y1990N        Y1991 Y1991F Y1991N  \
# 47       NaN     NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 49       NaN     NaN   -2388.8030     Fc    NaN   -2388.8030     Fc    NaN
# 67       NaN     NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 72       NaN     NaN     274.7953     Fc    NaN     223.9326     Fc    NaN
# 100      NaN     NaN   -2388.8030     Fc    NaN   -2388.8030     Fc    NaN
# ...      ...     ...          ...    ...    ...          ...    ...    ...
# 35722    NaN     NaN -700246.4587     Fc    NaN -700246.4587     Fc    NaN
# 35730    NaN     NaN -700246.4587     Fc    NaN -700246.4587     Fc    NaN
# 35738    NaN     NaN  666192.2989     Fc    NaN  656061.8437     Fc    NaN
# 35746    NaN     NaN  359718.4047     Fc    NaN  349587.9496     Fc    NaN
# 35752    NaN     NaN  306473.8942     Fc    NaN  306473.8942     Fc    NaN
#
#              Y1992 Y1992F Y1992N        Y1993 Y1993F Y1993N        Y1994  \
# 47          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 49      -2388.8030     Fc    NaN   -2388.8030     Fc    NaN   -2388.8030
# 67          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 72         65.2820     Fc    NaN      53.0891     Fc    NaN      44.2843
# 100     -2388.8030     Fc    NaN   -2388.8030     Fc    NaN   -2388.8030
# ...            ...    ...    ...          ...    ...    ...          ...
# 35722 -724412.0872     Fc    NaN -743285.5677     Fc    NaN -743494.4884
# 35730 -724412.0872     Fc    NaN -743285.5677     Fc    NaN -743494.4884
# 35738  662571.0752     Fc    NaN  665030.3946     Fc    NaN  665564.8765
# 35746  356097.1811     Fc    NaN  357877.5604     Fc    NaN  358412.0424
# 35752  306473.8942     Fc    NaN  307152.8342     Fc    NaN  307152.8342
#
#       Y1994F Y1994N        Y1995 Y1995F Y1995N        Y1996 Y1996F Y1996N  \
# 47        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 49        Fc    NaN   -2388.8030     Fc    NaN   -2388.8030     Fc    NaN
# 67        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 72        Fc    NaN      39.6372     Fc    NaN      34.3621     Fc    NaN
# 100       Fc    NaN   -2388.8030     Fc    NaN   -2388.8030     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35722     Fc    NaN -742949.5013     Fc    NaN -743142.3785     Fc    NaN
# 35730     Fc    NaN -742949.5013     Fc    NaN -743142.3785     Fc    NaN
# 35738     Fc    NaN  669454.5596     Fc    NaN  678365.8600     Fc    NaN
# 35746     Fc    NaN  362301.7254     Fc    NaN  371213.0258     Fc    NaN
# 35752     Fc    NaN  307152.8342     Fc    NaN  307152.8342     Fc    NaN
#
#              Y1997 Y1997F Y1997N        Y1998 Y1998F Y1998N        Y1999  \
# 47          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 49      -2388.8030     Fc    NaN   -2388.8030     Fc    NaN   -2388.8030
# 67          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 72         29.4031     Fc    NaN      27.2078     Fc    NaN      24.6911
# 100     -2388.8030     Fc    NaN   -2388.8030     Fc    NaN   -2388.8030
# ...            ...    ...    ...          ...    ...    ...          ...
# 35722 -743195.7041     Fc    NaN -742948.4334     Fc    NaN -742355.7111
# 35730 -743195.7041     Fc    NaN -742948.4334     Fc    NaN -742355.7111
# 35738  674961.7509     Fc    NaN  662907.9893     Fc    NaN  658266.3877
# 35746  367808.9167     Fc    NaN  355755.1551     Fc    NaN  351113.5535
# 35752  307152.8342     Fc    NaN  307152.8342     Fc    NaN  307152.8342
#
#       Y1999F Y1999N        Y2000 Y2000F Y2000N        Y2001 Y2001F Y2001N  \
# 47        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 49        Fc    NaN   -2388.8030     Fc    NaN     121.9016     Fc    NaN
# 67        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 72        Fc    NaN      25.0585     Fc    NaN      28.5361     Fc    NaN
# 100       Fc    NaN   -2388.8030     Fc    NaN     121.9016     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35722     Fc    NaN -741794.4557     Fc    NaN -720445.5264     Fc    NaN
# 35730     Fc    NaN -741794.4557     Fc    NaN -720445.5264     Fc    NaN
# 35738     Fc    NaN  665628.3107     Fc    NaN  614016.6573     Fc    NaN
# 35746     Fc    NaN  358475.4765     Fc    NaN  353580.8186     Fc    NaN
# 35752     Fc    NaN  307152.8342     Fc    NaN  260435.8387     Fc    NaN
#
#              Y2002 Y2002F Y2002N        Y2003 Y2003F Y2003N        Y2004  \
# 47          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 49        121.9016     Fc    NaN     121.9016     Fc    NaN     121.9016
# 67          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 72         37.4770     Fc    NaN      38.7123     Fc    NaN      41.6129
# 100       121.9016     Fc    NaN     121.9016     Fc    NaN     121.9016
# ...            ...    ...    ...          ...    ...    ...          ...
# 35722 -720545.7758     Fc    NaN -720738.7413     Fc    NaN -720826.5706
# 35730 -720545.7758     Fc    NaN -720738.7413     Fc    NaN -720826.5706
# 35738  609586.3067     Fc    NaN  607631.9538     Fc    NaN  620623.3373
# 35746  349150.4680     Fc    NaN  347196.1151     Fc    NaN  360187.4986
# 35752  260435.8387     Fc    NaN  260435.8387     Fc    NaN  260435.8387
#
#       Y2004F Y2004N        Y2005 Y2005F Y2005N        Y2006 Y2006F Y2006N  \
# 47        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 49        Fc    NaN     121.9016     Fc    NaN     121.9016     Fc    NaN
# 67        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 72        Fc    NaN      54.7141     Fc    NaN      98.5999     Fc    NaN
# 100       Fc    NaN     121.9016     Fc    NaN     121.9016     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35722     Fc    NaN -720883.6599     Fc    NaN -721004.3133     Fc    NaN
# 35730     Fc    NaN -720883.6599     Fc    NaN -721004.3133     Fc    NaN
# 35738     Fc    NaN  620434.3941     Fc    NaN  622303.6487     Fc    NaN
# 35746     Fc    NaN  359998.5554     Fc    NaN  361867.8100     Fc    NaN
# 35752     Fc    NaN  260435.8387     Fc    NaN  260435.8387     Fc    NaN
#
#              Y2007 Y2007F Y2007N        Y2008 Y2008F Y2008N        Y2009  \
# 47          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 49        121.9016     Fc    NaN     121.9016     Fc    NaN     121.9016
# 67          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 72         76.4629     Fc    NaN     149.2237     Fc    NaN     245.4437
# 100       121.9016     Fc    NaN     121.9016     Fc    NaN     121.9016
# ...            ...    ...    ...          ...    ...    ...          ...
# 35722 -721213.9582     Fc    NaN -721366.1169     Fc    NaN -721438.3387
# 35730 -721213.9582     Fc    NaN -721366.1169     Fc    NaN -721438.3387
# 35738  620288.5763     Fc    NaN  609606.3334     Fc    NaN  602739.7315
# 35746  359852.7376     Fc    NaN  349170.4947     Fc    NaN  342303.8928
# 35752  260435.8387     Fc    NaN  260435.8387     Fc    NaN  260435.8387
#
#       Y2009F Y2009N        Y2010 Y2010F Y2010N        Y2011 Y2011F Y2011N  \
# 47        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 49        Fc    NaN     121.9016     Fc    NaN    -246.2191     Fc    NaN
# 67        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 72        Fc    NaN     336.6644     Fc    NaN     393.0081     Fc    NaN
# 100       Fc    NaN     121.9016     Fc    NaN    -246.2191     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35722     Fc    NaN -721309.9239     Fc    NaN -857813.9526     Fc    NaN
# 35730     Fc    NaN -721309.9239     Fc    NaN -857813.9526     Fc    NaN
# 35738     Fc    NaN  607191.2813     Fc    NaN  499668.3155     Fc    NaN
# 35746     Fc    NaN  346755.4426     Fc    NaN  340465.9272     Fc    NaN
# 35752     Fc    NaN  260435.8387     Fc    NaN  159202.3883     Fc    NaN
#
#              Y2012 Y2012F Y2012N        Y2013 Y2013F Y2013N        Y2014  \
# 47          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 49       -246.2191     Fc    NaN    -246.2191     Fc    NaN    -246.2191
# 67          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 72        363.2833     Fc    NaN     256.0833     Fc    NaN     211.6509
# 100      -246.2191     Fc    NaN    -246.2191     Fc    NaN    -246.2191
# ...            ...    ...    ...          ...    ...    ...          ...
# 35722 -857872.6369     Fc    NaN -858058.5206     Fc    NaN -858203.2601
# 35730 -857872.6369     Fc    NaN -858058.5206     Fc    NaN -858203.2601
# 35738  490130.1544     Fc    NaN  490263.5536     Fc    NaN  481773.6392
# 35746  330927.7661     Fc    NaN  331061.1654     Fc    NaN  322571.2509
# 35752  159202.3883     Fc    NaN  159202.3883     Fc    NaN  159202.3883
#
#       Y2014F Y2014N        Y2015 Y2015F Y2015N        Y2016 Y2016F Y2016N  \
# 47        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 49        Fc    NaN    -246.2191     Fc    NaN     154.6574     Fc    NaN
# 67        Fc    NaN       0.0000     Fc    NaN       0.0000     Fc    NaN
# 72        Fc    NaN     231.8452     Fc    NaN     181.6056     Fc    NaN
# 100       Fc    NaN    -246.2191     Fc    NaN     154.6574     Fc    NaN
# ...      ...    ...          ...    ...    ...          ...    ...    ...
# 35722     Fc    NaN -858278.9241     Fc    NaN -559849.4148     Fc    NaN
# 35730     Fc    NaN -858278.9241     Fc    NaN -559849.4148     Fc    NaN
# 35738     Fc    NaN  477494.2221     Fc    NaN  525705.1453     Fc    NaN
# 35746     Fc    NaN  318291.8339     Fc    NaN  316627.0233     Fc    NaN
# 35752     Fc    NaN  159202.3883     Fc    NaN  209078.1221     Fc    NaN
#
#              Y2017 Y2017F Y2017N        Y2018 Y2018F Y2018N        Y2019  \
# 47          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 49        154.6574     Fc    NaN     154.6574     Fc    NaN     154.6574
# 67          0.0000     Fc    NaN       0.0000     Fc    NaN       0.0000
# 72        132.7927     Fc    NaN     132.8417     Fc    NaN     117.0798
# 100       154.6574     Fc    NaN     154.6574     Fc    NaN     154.6574
# ...            ...    ...    ...          ...    ...    ...          ...
# 35722 -559749.6061     Fc    NaN -559002.5668     Fc    NaN -559002.5668
# 35730 -559749.6061     Fc    NaN -559002.5668     Fc    NaN -559002.5668
# 35738  526789.2079     Fc    NaN  529536.3228     Fc    NaN  529808.3338
# 35746  317711.0859     Fc    NaN  320458.2007     Fc    NaN  320730.2118
# 35752  209078.1221     Fc    NaN  209078.1221     Fc    NaN  209078.1221
#
#       Y2019F Y2019N  Y2020 Y2020F  Y2020N  Y2030 Y2030F  Y2030N  Y2050 Y2050F  \
# 47        Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 49        Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 67        Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 72        Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 100       Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# ...      ...    ...    ...    ...     ...    ...    ...     ...    ...    ...
# 35722     Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 35730     Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 35738     Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 35746     Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
# 35752     Fc    NaN    NaN    NaN     NaN    NaN    NaN     NaN    NaN    NaN
#
#        Y2050N
# 47        NaN
# 49        NaN
# 67        NaN
# 72        NaN
# 100       NaN
# ...       ...
# 35722     NaN
# 35730     NaN
# 35738     NaN
# 35746     NaN
# 35752     NaN
#
# [2918 rows x 195 columns]

# %% [markdown]
# ## 3. Loading the *Population Stats* dataset

# %%
#Loading the population_stats dataset
pop_df_raw = pd.read_csv('https://raw.githubusercontent.com/nicoboou/ml_eml/main/data/pop_data_onu.csv',thousands=' ')
pop_df_raw
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ...       ...          ...    ...          ...   ...        ...        ...
# 280927    716     Zimbabwe    207  Lower 95 PI  2080     2080.5  10576.533
# 280928    716     Zimbabwe    207  Lower 95 PI  2085     2085.5  10293.349
# 280929    716     Zimbabwe    207  Lower 95 PI  2090     2090.5   9920.336
# 280930    716     Zimbabwe    207  Lower 95 PI  2095     2095.5   9503.711
# 280931    716     Zimbabwe    207  Lower 95 PI  2100     2100.5   9090.075
#
#         PopFemale   PopTotal  PopDensity
# 0        3652.874   7752.117      11.874
# 1        3705.395   7840.151      12.009
# 2        3761.546   7935.996      12.156
# 3        3821.348   8039.684      12.315
# 4        3884.832   8151.316      12.486
# ...           ...        ...         ...
# 280927  11255.983  21836.893      56.448
# 280928  11050.875  21355.988      55.205
# 280929  10767.709  20689.956      53.483
# 280930  10412.184  19892.080      51.421
# 280931   9996.105  19061.177      49.273
#
# [280932 rows x 10 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Before trying to preprocess the data in order to make use of it for our machine learning tasks, let's explore what we have & try to figure out some primary findings.

# %% [markdown]
# ## 1. Exploring the Agricultural Crop data

# %%
crops_all.head()
# Out:
#   Continent  Area Code     Area  Item Code                 Item  Element Code  \
# 0    Africa          4  Algeria        221  Almonds, with shell          5312
# 1    Africa          4  Algeria        221  Almonds, with shell          5419
# 2    Africa          4  Algeria        221  Almonds, with shell          5510
# 3    Africa          4  Algeria        515               Apples          5312
# 4    Africa          4  Algeria        515               Apples          5419
#
#           Element    Unit    Y1961    Y1962    Y1963    Y1964    Y1965  \
# 0  Area harvested      ha  13300.0  13300.0  13300.0  14200.0  13800.0
# 1           Yield   hg/ha   4511.0   4511.0   4511.0   4507.0   4493.0
# 2      Production  tonnes   6000.0   6000.0   6000.0   6400.0   6200.0
# 3  Area harvested      ha   3400.0   3100.0   2800.0   2700.0   2900.0
# 4           Yield   hg/ha  45294.0  45161.0  46429.0  46078.0  45348.0
#
#      Y1966    Y1967    Y1968    Y1969    Y1970    Y1971    Y1972    Y1973  \
# 0  12700.0  12900.0  10000.0   5500.0   6700.0   4600.0   8300.0   9200.0
# 1   4488.0   4510.0   4497.0   4484.0   4478.0   4500.0   4514.0   4502.0
# 2   5700.0   5818.0   4497.0   2466.0   3000.0   2070.0   3747.0   4142.0
# 3   2500.0   2500.0   2300.0   2600.0   2800.0   3000.0   2500.0   2200.0
# 4  44832.0  45456.0  45609.0  45681.0  46071.0  45020.0  45920.0  45736.0
#
#      Y1974    Y1975    Y1976    Y1977    Y1978    Y1979    Y1980    Y1981  \
# 0  10150.0  11000.0  18250.0  10400.0   7100.0   8100.0   8700.0  15960.0
# 1   4500.0   4542.0   4498.0   4487.0   4496.0   4483.0   4483.0   4969.0
# 2   4567.0   4996.0   8208.0   4666.0   3192.0   3631.0   3900.0   7930.0
# 3   3200.0   4300.0   3200.0   3800.0   3200.0   3000.0   4300.0   4600.0
# 4  45525.0  50174.0  45700.0  50471.0  48678.0  45520.0  50740.0  50839.0
#
#      Y1982    Y1983    Y1984    Y1985    Y1986    Y1987    Y1988    Y1989  \
# 0  15450.0  18030.0  16490.0  21100.0  20860.0  21000.0  21370.0  23610.0
# 1   4296.0   3934.0   4534.0   4716.0   3864.0   3930.0   4528.0   5268.0
# 2   6637.0   7093.0   7476.0   9951.0   8060.0   8253.0   9676.0  12438.0
# 3   4900.0   4800.0   7800.0   8000.0   8000.0   8700.0   8000.0  10200.0
# 4  49951.0  49825.0  49810.0  53000.0  50874.0  50216.0  49975.0  50387.0
#
#      Y1990    Y1991    Y1992    Y1993    Y1994    Y1995    Y1996    Y1997  \
# 0  25010.0  24240.0  24970.0  25880.0  26130.0  24860.0  25190.0  27440.0
# 1   4691.0   6505.0   7169.0   9538.0   7312.0   7992.0  13323.0   7069.0
# 2  11733.0  15768.0  17901.0  24685.0  19106.0  19869.0  33561.0  19396.0
# 3  10740.0  10960.0  11140.0  12020.0  11800.0  11930.0  12190.0  12260.0
# 4  36258.0  43638.0  55641.0  52753.0  41777.0  53764.0  60598.0  53446.0
#
#      Y1998    Y1999    Y2000    Y2001    Y2002    Y2003    Y2004    Y2005  \
# 0  26490.0  26820.0  27150.0  26980.0  27720.0  30630.0  30453.0  35099.0
# 1   8169.0   9546.0   9754.0   9340.0  11648.0  10524.0  12473.0  12929.0
# 2  21641.0  25602.0  26483.0  25199.0  32287.0  32234.0  37985.0  45379.0
# 3  12870.0  13020.0  13480.0  14040.0  15240.0  18080.0  19861.0  24279.0
# 4  58574.0  67065.0  71600.0  74715.0  79421.0  74968.0  83265.0  82257.0
#
#      Y2006    Y2007    Y2008    Y2009    Y2010    Y2011    Y2012    Y2013  \
# 0  39098.0  40890.0  39787.0  39313.0  54485.0  52245.0  49975.0  49011.0
# 1  13728.0   8342.0   9933.0  12055.0  10457.0   9689.0  13304.0  12965.0
# 2  53673.0  34110.0  39521.0  47393.0  56973.0  50621.0  66487.0  63545.0
# 3  28658.0  31904.0  33206.0  36616.0  52419.0  51080.0  48828.0  48064.0
# 4  98835.0  59557.0  78590.0  73047.0  72233.0  79112.0  81414.0  94860.0
#
#       Y2014     Y2015     Y2016     Y2017     Y2018     Y2019
# 0   39050.0   40403.0   49983.0   50100.0   43043.0   35380.0
# 1   16601.0   18930.0   13223.0   12362.0   13292.0   20467.0
# 2   64827.0   76482.0   66095.0   61934.0   57213.0   72412.0
# 3   40418.0   41011.0   46070.0   44620.0   39034.0   32989.0
# 4  114507.0  110086.0  108716.0  110766.0  124970.0  169399.0

# %%
crops_all.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38146 entries, 0 to 1653
# Data columns (total 67 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Continent     38146 non-null  object
#  1   Area Code     38146 non-null  int64
#  2   Area          38146 non-null  object
#  3   Item Code     38146 non-null  int64
#  4   Item          38146 non-null  object
#  5   Element Code  38146 non-null  int64
#  6   Element       38146 non-null  object
#  7   Unit          38146 non-null  object
#  8   Y1961         22639 non-null  float64
#  9   Y1962         22658 non-null  float64
#  10  Y1963         22656 non-null  float64
#  11  Y1964         22683 non-null  float64
#  12  Y1965         22683 non-null  float64
#  13  Y1966         22780 non-null  float64
#  14  Y1967         22815 non-null  float64
#  15  Y1968         22878 non-null  float64
#  16  Y1969         22911 non-null  float64
#  17  Y1970         22997 non-null  float64
#  18  Y1971         23070 non-null  float64
#  19  Y1972         23099 non-null  float64
#  20  Y1973         23098 non-null  float64
#  21  Y1974         23157 non-null  float64
#  22  Y1975         23292 non-null  float64
#  23  Y1976         23353 non-null  float64
#  24  Y1977         23511 non-null  float64
#  25  Y1978         23548 non-null  float64
#  26  Y1979         23713 non-null  float64
#  27  Y1980         23929 non-null  float64
#  28  Y1981         24019 non-null  float64
#  29  Y1982         24094 non-null  float64
#  30  Y1983         24151 non-null  float64
#  31  Y1984         24213 non-null  float64
#  32  Y1985         25680 non-null  float64
#  33  Y1986         25844 non-null  float64
#  34  Y1987         25962 non-null  float64
#  35  Y1988         26113 non-null  float64
#  36  Y1989         26264 non-null  float64
#  37  Y1990         27470 non-null  float64
#  38  Y1991         27694 non-null  float64
#  39  Y1992         30712 non-null  float64
#  40  Y1993         30939 non-null  float64
#  41  Y1994         31221 non-null  float64
#  42  Y1995         31398 non-null  float64
#  43  Y1996         31480 non-null  float64
#  44  Y1997         31654 non-null  float64
#  45  Y1998         31791 non-null  float64
#  46  Y1999         32016 non-null  float64
#  47  Y2000         32352 non-null  float64
#  48  Y2001         32431 non-null  float64
#  49  Y2002         32485 non-null  float64
#  50  Y2003         32762 non-null  float64
#  51  Y2004         32938 non-null  float64
#  52  Y2005         32996 non-null  float64
#  53  Y2006         33179 non-null  float64
#  54  Y2007         32727 non-null  float64
#  55  Y2008         32746 non-null  float64
#  56  Y2009         32771 non-null  float64
#  57  Y2010         32836 non-null  float64
#  58  Y2011         32848 non-null  float64
#  59  Y2012         32933 non-null  float64
#  60  Y2013         32933 non-null  float64
#  61  Y2014         32987 non-null  float64
#  62  Y2015         33010 non-null  float64
#  63  Y2016         33042 non-null  float64
#  64  Y2017         33100 non-null  float64
#  65  Y2018         33392 non-null  float64
#  66  Y2019         33437 non-null  float64
# dtypes: float64(59), int64(3), object(5)
# memory usage: 19.8+ MB

# %%
crops_all.describe(include = 'all').T
# Out:
#              count unique                      top   freq           mean  \
# Continent    38146      5                   Europe  10557            NaN
# Area Code  38146.0    NaN                      NaN    NaN     130.297069
# Area         38146    210          China, mainland    398            NaN
# Item Code  38146.0    NaN                      NaN    NaN     614.361663
# Item         38146    175  Roots and Tubers, Total    618            NaN
# ...            ...    ...                      ...    ...            ...
# Y2015      33010.0    NaN                      NaN    NaN  711842.130233
# Y2016      33042.0    NaN                      NaN    NaN   722969.65786
# Y2017      33100.0    NaN                      NaN    NaN  738894.115952
# Y2018      33392.0    NaN                      NaN    NaN  734436.155127
# Y2019      33437.0    NaN                      NaN    NaN  742458.525197
#
#                        std   min      25%      50%        75%          max
# Continent              NaN   NaN      NaN      NaN        NaN          NaN
# Area Code        75.053504   1.0     63.0    126.0      196.0        299.0
# Area                   NaN   NaN      NaN      NaN        NaN          NaN
# Item Code       547.910943  15.0    236.0    446.0      656.0       1841.0
# Item                   NaN   NaN      NaN      NaN        NaN          NaN
# ...                    ...   ...      ...      ...        ...          ...
# Y2015       9973667.916526   0.0   3200.0  23082.5  122509.25  750290277.0
# Y2016      10249828.135251   0.0  3191.25  22985.0  123213.75  768594154.0
# Y2017      10171664.733574   0.0   3191.0  22932.0  124309.25  758646205.0
# Y2018      10245919.307647   0.0  2476.25  21138.0  121818.75  747060316.0
# Y2019      10346386.885358   0.0   2470.0  21430.0   121779.0  752895389.0
#
# [67 rows x 11 columns]

# %%
crops_all["Element"].unique()
# Out:
# array(['Area harvested', 'Yield', 'Production'], dtype=object)

# %% [markdown]
# It appears that we have data on 3 main elements thanks to this dataset:
# - Area harvested
# - Yield
# - Production

# %% [markdown]
# **Let's inspect missing values**

# %%
crops_all.isnull().describe().T
# Out:
#            count unique    top   freq
# Continent  38146      1  False  38146
# Area Code  38146      1  False  38146
# Area       38146      1  False  38146
# Item Code  38146      1  False  38146
# Item       38146      1  False  38146
# ...          ...    ...    ...    ...
# Y2015      38146      2  False  33010
# Y2016      38146      2  False  33042
# Y2017      38146      2  False  33100
# Y2018      38146      2  False  33392
# Y2019      38146      2  False  33437
#
# [67 rows x 4 columns]

# %%
df = pd.DataFrame(crops_all.isnull().sum().sort_index()/len(crops_all))
df.sort_values(by=0,ascending=False).head(50)
# Out:
#               0
# Y1961  0.406517
# Y1963  0.406071
# Y1962  0.406019
# Y1965  0.405364
# Y1964  0.405364
# Y1966  0.402821
# Y1967  0.401903
# Y1968  0.400252
# Y1969  0.399387
# Y1970  0.397132
# Y1971  0.395218
# Y1973  0.394484
# Y1972  0.394458
# Y1974  0.392938
# Y1975  0.389399
# Y1976  0.387800
# Y1977  0.383658
# Y1978  0.382688
# Y1979  0.378362
# Y1980  0.372700
# Y1981  0.370340
# Y1982  0.368374
# Y1983  0.366880
# Y1984  0.365255
# Y1985  0.326797
# Y1986  0.322498
# Y1987  0.319404
# Y1988  0.315446
# Y1989  0.311487
# Y1990  0.279872
# Y1991  0.274000
# Y1992  0.194883
# Y1993  0.188932
# Y1994  0.181539
# Y1995  0.176899
# Y1996  0.174750
# Y1997  0.170188
# Y1998  0.166597
# Y1999  0.160698
# Y2000  0.151890
# Y2001  0.149819
# Y2002  0.148404
# Y2007  0.142059
# Y2008  0.141561
# Y2003  0.141142
# Y2009  0.140906
# Y2010  0.139202
# Y2011  0.138887
# Y2012  0.136659
# Y2013  0.136659

# %% [markdown]
# We clearly see that the earlier the data came from, the less information we have, and it's **normal**.

# %% [markdown]
# **What is the rank per category & country ?**

# %%
continents = crops_all['Continent'].unique()
areas = crops_all['Area'].unique()
items = crops_all['Item'].unique()
elements = crops_all['Element'].unique()

# %%
def show_data(df, continent, area, item, element, year):
    year = "Y" + str(year)

    # ALL countries, 1 item, ALL element => 3 barplots ('Total Area Harvested, Yield & production of ITEM per country per YEAR with slider')
    if (area == "ALL") & (element == "ALL"):
        for el in df["Element"].unique():
            to_plot = df[
                (df["Continent"] == continent)
                & (df["Element"] == el)
                & (df["Item"] == item)
            ][[year, "Area"]]
            fig = px.bar(
                to_plot,
                x="Area",
                y=year,
                labels={
                    year: "Total "
                    + str(el)
                    + " ("
                    + str(df[(df["Element"] == el)]["Unit"].unique()[0])
                    + ")",
                    "Area": "Countries",
                },
                title="Total "
                + str(el)
                + " of "
                + str(item)
                + " per country in "
                + str(continent)
                + " ("
                + str(year[1:])
                + ")",
                width=1000,
                height=500,
                template="plotly",
            )

            fig.show()

    # ALL countries, 1 item, 1 element => 1 barplot ('ELEMENT of ITEM per country per YEAR with slider')
    elif (area == "ALL") & (element != "ALL"):
        to_plot = df[
            (df["Continent"] == continent)
            & (df["Element"] == element)
            & (df["Item"] == item)
        ][[year, "Area"]]
        fig = px.bar(
            to_plot,
            x="Area",
            y=year,
            labels={
                year: "Total "
                + str(element)
                + " "
                + df[df["Element"] == element]["Unit"].unique()[0],
                "Area": "Countries",
            },
            title="Total "
            + str(element)
            + " of "
            + str(item)
            + " per country in "
            + str(continent)
            + " ("
            + str(year[1:])
            + ")",
            width=1000,
            height=500,
            template="plotly",
        )
        fig.show()

    # 1 country, 1 item, ALL elements => 3 lineplots ('Area harvested', 'Yield','Production') per YEAR (linegrah, no slider)
    elif area != "ALL":
        if element == "ALL":
            for el in df["Element"].unique():
                tmp_df = df[
                    (df["Continent"] == continent)
                    & (df["Element"] == el)
                    & (df["Area"] == area)
                    & (df["Item"] == item)
                ].drop(
                    columns=[
                        "Continent",
                        "Area Code",
                        "Area",
                        "Item Code",
                        "Item",
                        "Element Code",
                        "Element",
                        "Unit",
                    ]
                )
                to_plot = tmp_df.T.set_axis(["Value"], axis=1, inplace=False)
                to_plot.index = to_plot.index.map(lambda x: x[1:])
                to_plot.index = to_plot.index.map(lambda x: "01/01/" + str(x))
                to_plot.index = pd.to_datetime(to_plot.index)
                to_plot.index.names = ["Year"]
                fig = px.line(
                    to_plot,
                    x=to_plot.index,
                    y="Value",
                    labels={
                        "Value": "Total "
                        + str(el)
                        + " of "
                        + str(item)
                        + " ("
                        + str(df[(df["Element"] == el)]["Unit"].unique()[0])
                        + ")"
                    },
                    title="Evolution of the Total "
                    + str(el)
                    + " of "
                    + str(item)
                    + " in "
                    + str(area),
                    width=1000,
                    height=500,
                    template="plotly",
                )
                fig.show()
        else:
            tmp_df = df[
                (df["Continent"] == continent)
                & (df["Element"] == element)
                & (df["Area"] == area)
                & (df["Item"] == item)
            ].drop(
                columns=[
                    "Continent",
                    "Area Code",
                    "Area",
                    "Item Code",
                    "Item",
                    "Element Code",
                    "Element",
                    "Unit",
                ]
            )
            to_plot = tmp_df.T.set_axis(["Value"], axis=1, inplace=False)
            to_plot.index = to_plot.index.map(lambda x: x[1:])
            to_plot.index = to_plot.index.map(lambda x: "01/01/" + str(x))
            to_plot.index = pd.to_datetime(to_plot.index)
            to_plot.index.names = ["Year"]
            fig = px.line(
                to_plot,
                x=to_plot.index,
                y="Value",
                labels={
                    "Value": "Total "
                    + str(element)
                    + " of "
                    + str(item)
                    + " ("
                    + str(df[(df["Element"] == element)]["Unit"].unique()[0])
                    + ")"
                },
                title="Evolution of the Total "
                + str(element)
                + " of "
                + str(item)
                + " in "
                + str(area),
                width=1000,
                height=500,
                template="plotly",
            )
            fig.show()

# %%
show_data(crops_all, "Europe", "France", "Wheat", "Yield", "1986")
# Out:
# <div>                            <div id="6b0692e6-5d20-409b-8fa0-a8899ecc4bfc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b0692e6-5d20-409b-8fa0-a8899ecc4bfc")) {                    Plotly.newPlot(                        "6b0692e6-5d20-409b-8fa0-a8899ecc4bfc",                        [{"hovertemplate":"Year=%{x}<br>Total Yield of Wheat (hg/ha)=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1961-01-01T00:00:00","1962-01-01T00:00:00","1963-01-01T00:00:00","1964-01-01T00:00:00","1965-01-01T00:00:00","1966-01-01T00:00:00","1967-01-01T00:00:00","1968-01-01T00:00:00","1969-01-01T00:00:00","1970-01-01T00:00:00","1971-01-01T00:00:00","1972-01-01T00:00:00","1973-01-01T00:00:00","1974-01-01T00:00:00","1975-01-01T00:00:00","1976-01-01T00:00:00","1977-01-01T00:00:00","1978-01-01T00:00:00","1979-01-01T00:00:00","1980-01-01T00:00:00","1981-01-01T00:00:00","1982-01-01T00:00:00","1983-01-01T00:00:00","1984-01-01T00:00:00","1985-01-01T00:00:00","1986-01-01T00:00:00","1987-01-01T00:00:00","1988-01-01T00:00:00","1989-01-01T00:00:00","1990-01-01T00:00:00","1991-01-01T00:00:00","1992-01-01T00:00:00","1993-01-01T00:00:00","1994-01-01T00:00:00","1995-01-01T00:00:00","1996-01-01T00:00:00","1997-01-01T00:00:00","1998-01-01T00:00:00","1999-01-01T00:00:00","2000-01-01T00:00:00","2001-01-01T00:00:00","2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00"],"xaxis":"x","y":[23950.0,30752.0,26624.0,31534.0,32655.0,28296.0,36365.0,36641.0,35809.0,34223.0,38614.0,45698.0,45067.0,45844.0,38734.0,37722.0,42303.0,50323.0,47820.0,51810.0,50110.0,52360.0,51274.0,64597.0,59999.0,54487.0,55584.0,61509.0,63480.0,64787.0,66764.0,63992.0,64739.0,66685.0,65079.0,71361.0,66288.0,76063.0,72395.0,71175.0,66169.0,74455.0,62500.0,75788.0,69887.0,67414.0,62542.0,71018.0,74478.0,70405.0,66563.0,71512.0,72656.0,73530.0,78008.0,52896.0,72538.0,67680.0,77428.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %% [markdown]
# **Let's now have a look at the scatter matrix, which is a statistic that is used to make estimates of the covariance matrix, for instance of the multivariate normal distribution.**

# %%
#from pandas.plotting import scatter_matrix

#scatter_matrix(df, figsize=(12, 8))
#plt.show()

# %% [markdown]
# **What are the most productive types of crops ? Wheat ? Barley ? Something else ? Let's see**

# %%
## Somme des rendements pour l'année 2019 pour tous les pays, pour les 165 variétés

# %% [markdown]
# **What could be interesting is to see the share of production of ANY FOOD ELEMENT per country**

# %%
def show_descriptive_scatter(df, item):
    #FIRST, since we do not have the same number of data for the different elements, let's select only the items where we have all the 3 infos
    items_to_drop = list(set(df["Item"].unique()) - set(df[(df["Element"] == "Yield")]["Item"].unique()))
    to_plot = df[~df["Item"].isin(items_to_drop)]
    
    #Let's now drop the columns we do not need
    to_plot = to_plot[(to_plot["Item"] == item)].drop(
        columns=[
            "Area Code",
            "Item Code",
            "Item",
            "Element Code",
            "Unit",
        ]
    )
    #let's deflate our df to put all our "Year" columns in a single column
    to_plot = to_plot.melt(
        id_vars=["Continent", "Area","Element"], var_name="Year", value_name="Value"
    )
    
    # Drop countries without all info because not all countries harvest or have this info for THIS particular item
    countries_to_drop = list(set(to_plot["Area"].unique()) - set(to_plot[(to_plot["Element"] == "Yield")]["Area"].unique()))
    to_plot = to_plot[~to_plot["Area"].isin(countries_to_drop)]
    
    #Some small slicing to get the Year
    to_plot["Year"] = to_plot["Year"].apply(lambda x: x[1:])
    
    #Fill NaN values with 0 to be able to plot
    to_plot["Value"] = to_plot["Value"].fillna(0)
    
    #Define our variables for our plot
    Area_harvested = to_plot[to_plot["Element"] == "Area harvested"]["Value"]
    Production = to_plot[to_plot["Element"] == "Production"]["Value"]
    size = to_plot[to_plot["Element"] == "Yield"]["Value"]
    countries = to_plot[to_plot["Element"] == "Production"]["Area"]
    years = to_plot[to_plot["Element"] == "Production"]["Year"]
    continents = to_plot[to_plot["Element"] == "Production"]["Continent"]
    
    #Plot our scatter plot
    fig = px.scatter(
        to_plot,
        x = Area_harvested,
        y = Production,
        animation_frame=years,
        animation_group=countries,
        size = size,
        color=continents,
        hover_name=countries,
        facet_col=continents,
        log_x=True,
        size_max=30,
        range_x=[1, max(x)],
        range_y=[1, max(y)],
    )
    fig.show()

# %%
show_descriptive_scatter(crops_all, "Wheat")
# Out:
# <div>                            <div id="85975a06-1b39-4299-91a2-6fb4be63a2ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85975a06-1b39-4299-91a2-6fb4be63a2ff")) {                    Plotly.newPlot(                        "85975a06-1b39-4299-91a2-6fb4be63a2ff",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>color=Africa<br>animation_frame=1961<br>facet_col=Africa<br>x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","hovertext":["Algeria","Angola","Botswana","Burundi","Cameroon","Chad","Democratic Republic of the Congo","Egypt","Eritrea","Eswatini","Ethiopia","Ethiopia PDR","Kenya","Lesotho","Libya","Madagascar","Malawi","Mali","Mauritania","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Somalia","South Africa","Sudan","Sudan (former)","Tunisia","Uganda","United Republic of Tanzania","Zambia","Zimbabwe"],"ids":["Algeria","Angola","Botswana","Burundi","Cameroon","Chad","Democratic Republic of the Congo","Egypt","Eritrea","Eswatini","Ethiopia","Ethiopia PDR","Kenya","Lesotho","Libya","Madagascar","Malawi","Mali","Mauritania","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Somalia","South Africa","Sudan","Sudan (former)","Tunisia","Uganda","United Republic of Tanzania","Zambia","Zimbabwe"],"legendgroup":"Africa","marker":{"color":"#636efa","size":[4060.0,11111.0,25000.0,4444.0,0.0,11111.0,7090.0,24697.0,0.0,0.0,0.0,7127.0,10907.0,8648.0,2829.0,0.0,15000.0,15000.0,2222.0,4528.0,7652.0,9867.0,12270.0,17778.0,7869.0,0.0,6190.0,0.0,16098.0,5471.0,0.0,7625.0,16000.0,14673.0],"sizemode":"area","sizeref":118.53,"symbol":"circle"},"mode":"markers","name":"Africa","orientation":"v","showlegend":true,"x":[1689064.0,18000.0,160.0,9000.0,0.0,1350.0,3000.0,581409.0,0.0,0.0,0.0,912000.0,100300.0,66532.0,106000.0,0.0,100.0,2500.0,450.0,1590000.0,11500.0,600.0,815.0,9000.0,1525.0,0.0,1407000.0,0.0,16400.0,850000.0,0.0,8000.0,380.0,550.0],"xaxis":"x","y":[685723.0,20000.0,400.0,4000.0,0.0,1500.0,2127.0,1435926.0,0.0,0.0,0.0,650000.0,109400.0,57540.0,29992.0,0.0,150.0,3750.0,100.0,720000.0,8800.0,592.0,1000.0,16000.0,1200.0,0.0,871000.0,0.0,26400.0,465000.0,0.0,6100.0,608.0,807.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>color=Americas<br>animation_frame=1961<br>facet_col=Americas<br>x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","hovertext":["Argentina","Bolivia (Plurinational State of)","Brazil","Canada","Chile","Colombia","Ecuador","Guatemala","Honduras","Mexico","Paraguay","Peru","United States of America","Uruguay","Venezuela (Bolivarian Republic of)"],"ids":["Argentina","Bolivia (Plurinational State of)","Brazil","Canada","Chile","Colombia","Ecuador","Guatemala","Honduras","Mexico","Paraguay","Peru","United States of America","Uruguay","Venezuela (Bolivarian Republic of)"],"legendgroup":"Americas","marker":{"color":"#EF553B","size":[12950.0,5625.0,5330.0,7529.0,13398.0,8881.0,9924.0,7319.0,7824.0,16758.0,9000.0,10012.0,16070.0,8523.0,5403.0],"sizemode":"area","sizeref":118.53,"symbol":"circle"},"mode":"markers","name":"Americas","orientation":"v","showlegend":true,"x":[4420900.0,80000.0,1022234.0,10245000.0,769200.0,160000.0,78770.0,33686.0,1025.0,836538.0,8000.0,153417.0,20870000.0,435912.0,2273.0],"xaxis":"x2","y":[5725000.0,45000.0,544858.0,7713000.0,1030560.0,142100.0,78170.0,24656.0,802.0,1401909.0,7200.0,153595.0,33539008.0,371536.0,1228.0],"yaxis":"y2","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>color=Asia<br>animation_frame=1961<br>facet_col=Asia<br>x=%{x}<br>y=%{y}<br>size=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Armenia","Azerbaijan","Bangladesh","Bhutan","China, mainland","China, Taiwan Province of","Cyprus","Democratic People's Republic of Korea","Georgia","I ...

# %%
def show_interactive_map(df, item, element):
    to_plot = df[(df["Item"] == item) & (df["Element"] == element)].drop(
        columns=[
            "Area Code",
            "Item Code",
            "Item",
            "Element Code",
            "Element",
            "Unit",
        ]
    )
    to_plot = to_plot.melt(
        id_vars=["Continent", "Area"], var_name="Year", value_name="Value"
    )
    to_plot["Year"] = to_plot["Year"].apply(lambda x: x[1:])
    to_plot["Value"] = to_plot["Value"].fillna(0)
    fig = px.scatter_geo(
        to_plot,
        locations="Area",
        locationmode="country names",  # ‘ISO-3’, ‘USA-states’, or ‘country names’
        color="Continent",  # Values from this column or array_like are used to assign color to marks
        hover_name="Area",
        size="Value",  # size of circles
        animation_frame="Year",
        # projection="equirectangular",
        size_max=50,
        width=1000,
        height=580,
        template="plotly",
        title=f"Evolution of the total {element} of {item}",
    )
    fig.show()

# %%
show_interactive_map(crops_all,"Wheat","Production")
# Out:
# <div>                            <div id="ec6713aa-c756-404b-a848-eea0ffa9ab72" class="plotly-graph-div" style="height:580px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec6713aa-c756-404b-a848-eea0ffa9ab72")) {                    Plotly.newPlot(                        "ec6713aa-c756-404b-a848-eea0ffa9ab72",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Continent=Africa<br>Year=1961<br>Value=%{marker.size}<br>Area=%{location}<extra></extra>","hovertext":["Algeria","Angola","Botswana","Burundi","Cameroon","Chad","Democratic Republic of the Congo","Egypt","Eritrea","Eswatini","Ethiopia","Ethiopia PDR","Kenya","Lesotho","Libya","Madagascar","Malawi","Mali","Mauritania","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Somalia","South Africa","South Sudan","Sudan","Sudan (former)","Tunisia","Uganda","United Republic of Tanzania","Zambia","Zimbabwe"],"legendgroup":"Africa","locationmode":"country names","locations":["Algeria","Angola","Botswana","Burundi","Cameroon","Chad","Democratic Republic of the Congo","Egypt","Eritrea","Eswatini","Ethiopia","Ethiopia PDR","Kenya","Lesotho","Libya","Madagascar","Malawi","Mali","Mauritania","Morocco","Mozambique","Namibia","Niger","Nigeria","Rwanda","Somalia","South Africa","South Sudan","Sudan","Sudan (former)","Tunisia","Uganda","United Republic of Tanzania","Zambia","Zimbabwe"],"marker":{"color":"#636efa","size":[685723.0,20000.0,400.0,4000.0,0.0,1500.0,2127.0,1435926.0,0.0,0.0,0.0,650000.0,109400.0,57540.0,29992.0,0.0,150.0,3750.0,100.0,720000.0,8800.0,592.0,1000.0,16000.0,1200.0,0.0,871000.0,0.0,0.0,26400.0,465000.0,0.0,6100.0,608.0,807.0],"sizemode":"area","sizeref":53696.52,"symbol":"circle"},"mode":"markers","name":"Africa","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Continent=Americas<br>Year=1961<br>Value=%{marker.size}<br>Area=%{location}<extra></extra>","hovertext":["Argentina","Bolivia (Plurinational State of)","Brazil","Canada","Chile","Colombia","Ecuador","Guatemala","Honduras","Mexico","Paraguay","Peru","United States of America","Uruguay","Venezuela (Bolivarian Republic of)"],"legendgroup":"Americas","locationmode":"country names","locations":["Argentina","Bolivia (Plurinational State of)","Brazil","Canada","Chile","Colombia","Ecuador","Guatemala","Honduras","Mexico","Paraguay","Peru","United States of America","Uruguay","Venezuela (Bolivarian Republic of)"],"marker":{"color":"#EF553B","size":[5725000.0,45000.0,544858.0,7713000.0,1030560.0,142100.0,78170.0,24656.0,802.0,1401909.0,7200.0,153595.0,33539008.0,371536.0,1228.0],"sizemode":"area","sizeref":53696.52,"symbol":"circle"},"mode":"markers","name":"Americas","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Continent=Asia<br>Year=1961<br>Value=%{marker.size}<br>Area=%{location}<extra></extra>","hovertext":["Afghanistan","Armenia","Azerbaijan","Bangladesh","Bhutan","China, mainland","China, Taiwan Province of","Cyprus","Democratic People's Republic of Korea","Georgia","India","Iran (Islamic Republic of)","Iraq","Israel","Japan","Jordan","Kazakhstan","Kuwait","Kyrgyzstan","Lebanon","Mongolia","Myanmar","Nepal","Oman","Pakistan","Palestine","Qatar","Republic of Korea","Saudi Arabia","Syrian Arab Republic","Tajikistan","Thailand","Turkey","Turkmenistan","United Arab Emirates","Uzbekistan","Yemen"],"legendgroup":"Asia","locationmode":"country names","locations":["Afghanistan","Armenia","Azerbaijan","Bangladesh","Bhutan","China, mainland","China, Taiwan Province of","Cyprus","Democratic People's Republic of Korea","Georgia","India","Iran (Islamic Republic of)","Iraq","Israel","Japan","Jordan","Kazakhstan","Kuwait","Kyrgyzstan","Lebanon","Mongolia","Myanmar","Nepal","Oman","Pakistan","Palestine ...

# %% [markdown]
# ## 2. Exploring the Gas Emissions data

# %% [markdown]
# **Share of worldwide CO2 emissions per category**

# %%
categories =

# %% [markdown]
# **Let's try to consolidate the CO2 total emissions per year in a new df**

# %%
### MEMO: calculer dans un nouveau df le total d'émissions de CO2 par année

# %% [markdown]
# **What are the countries that emit most CO2 emissions ? Is is correlated to their total agricultural production ?**

# %%
## 1. Merge both datasets (total of production, total of emissions) to have a emissions_crops df
## emissions_crops = pd.merge(total_crops_prod,total_emissions, on='',how='inner', suffixes=('_prod','_co2'))
## 2. Plot the corr matrix
## 3. Plot two bar plots: top 10 countries who emit the most // top 10 countries who produce the most

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Regression Model

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# We choose to preprocess the data according to the use we will make of it. Thus we will preprocess the data in order to have **numerical, approximately symmetrically distributed data** for our **regression** model.

# %% [markdown]
# **Some outliers ? Let's make a non-linear re-expression of the dependent variables using the logarithm.**

# %%
# Use of the log function

#We first keep the values inside a list
#list_to_build = df['column'].tolist()

#We then apply the log function on it
#df['column'] = np.log(df['column'])

# %% [markdown]
# **Some categorical variables ? Let's encode them into numerical ones to be able to use them in our regression model, and also fill the missing values with the median for each corresponding feature**

# %%
#df['column'].astype('category').cat.codes
#df, y, nas = proc_df(df_raw, 'target_variable') => Target Variable needs to be the CO2 emissions here !!!

# %% [markdown]
# **Save the pre-processed data into a *feather* file**

# %%
path_to_tmp = os.path.join(path_to_repo, "data", "tmp")

# %%
path_to_tmp

# %%
os.makedirs(path_to_tmp, exist_ok = True)

# %%
path_to_bulldozers_raw = os.path.join(path_to_tmp, 'bulldozers-raw')

# %%
df_raw.to_feather(path_to_bulldozers_raw)

# %% [markdown]
# ### Model Building: predict the CO2 emissions of a country depending on its production

# %% [markdown]
# **Cross-validation**

# %% [markdown]
# **Let's plot the graph**

# %%
#fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (15, 10), dpi = 300)
#plot_tree(model, filled = True)

# %% [markdown]
# ## Time-series Analysis #1: Worldwide Wheat Production

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# In order to be able to make any use of our data in a time series analysis purpose, we will transform our datasets so that we have **dates** as index.

# %%
df = crops_all.set_index(list(crops_all.columns[:7]))
#df = pd.MultiIndex.from_frame(df)
#df = df.to_frame()
df.T.loc[['Y1986']]

# %%
### MEMO: trop complexe, focus simplement sur le blé + enlever les codes

# %% [markdown]
# ### Analysis

# %% [markdown]
# **Resampling & Aggregation**

# %% [markdown]
# *Resample data by year using agg() function*

# %%
aggregated = df['Wheat'].resample('Y').agg(['mean','std','min','max'])
aggregated['mean'].plot(label='Mean per Year')
plt.fill_between(aggregated.index,aggregated['max'], aggregated['min'],alpha=0.2,label='min-max per year')
plt.legend()
plt.show()

# %% [markdown]
# *Resample & get standard deviation per year to see how much wheat production is volatile*

# %%
#df.loc['1961:2019','Wheat'].resample('Y').std().plot()
#plt.show()

# %% [markdown]
# *Resample & plot multiple graphs*

# %%
plt.figure(figsize=(13,9))
df.loc['1961:2019','Wheat'].plot()
df.loc['1961:2019','Wheat'].resample('Y').mean().plot(label="Mean per Year",lw=3,ls=':',alpha=0.8)
df.loc['1961:2019','Wheat'].resample('Decade ?????').mean().plot(label="Mean per Decade",lw=2,ls='--',alpha=0.8)
plt.legend()
plt.show()

# %% [markdown]
# **What do we seek to analyse?**<br/>
# Before applying any statistical model on a Time Series & forecast some predictions over it, our series has to be on a *stationary state*, which means that, over different time periods,
# - the mean should be a *constant* (visually parallel to the x-axis)
# - the standard deviation should be a *constant* (visually parallel to the x-axis)
# - auto-covariance should not depend on time.
#
# **Why does a time-series has to be stationary to be forecasted?**<br/>
# In case a time series has a particular behavior over a time interval, then there's a high probability that over a different interval, this behavior will be the same if the series is **stationary**. Thus it is very helpful to accurately forecast.
#
# **What elements infer on this stationarity?**
# Several elements play a role:
# - Trend: general direction of a time series over a certain period of time
# - Seasonality: seasonal variances (often explained by external factors)
# - Noise: irregularity in the data represented by spikes & downs at random
# - Cyclicity: cyclic behavior of data

# %% [markdown]
# **Moving Average**

# %% [markdown]
# In order to first analyse the mean, we could plot the overall average by taking each value & divide by *N*.<br/>But instead of averaging all the values at once, we will compute the mean of the values on a certain ***window*** that we will roll through our sample.<br/> By modifying the **window** parameter, we smooth more or less our mean since we add more or less values as the numerator, over the denominator which is the chosen number of periods to evaluate. <br/><br/>
# This allows to erase **transitory fluctuations** & keep the **long-term trend**, but it also gives us a **visual hint** that our time series **is** or **is not** ***stationary***.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/nicoboou/ml_eml/main/img/moving-averages.gif" width="500" align="center">

# %% [markdown]
# The successive calculation of moving averages for the same sequence of numbers requires that all the values used by the previous averages be retained ${\bar {x}}_{n}$, in order to replace the oldest term $x_{n-\mathrm {N}}$ with the most recent term $x_{n}$.

# %% [markdown]
# $${\displaystyle {\bar {x}}_{n}={\frac {1}{\mathrm {N} }}\ \displaystyle {\sum _{k=0}^{N-1}\;{x_{n-k}}}{\text{, or also }}{\bar {x}}_{n}={\bar {x}}_{n-1}+{\frac {x_{n}-x_{n-\mathrm {N} }}{\mathrm {N} }}}$$

# %%
df.loc['1961:2019','Wheat'].plot()
df.loc['1961:2019','Wheat'].rolling(window=1, freq='Y').mean().plot(label='moving average',lw=3,ls=':',alpha=0.8)
df.loc['1961:2019','Wheat'].rolling(window=1, freq='Y',center=True).mean().plot(label='moving average',lw=3,ls=':',alpha=0.8)

# %% [markdown]
# **Exponential Weighted Moving Average (EWMA)**

# %% [markdown]
# Compared to simple moving averages, EMAs give greater weight to recent (more relevant) data. <br/>
# Indeed in a standard moving average, the oldest price in a fixed series is dropped. By contrast, all prices in a chart influence an exponential moving average: older prices gradually diminish in significance, this time **exponentially** (in contrast with Simple WMA).

# %% [markdown]
# The EMA for a series ${\displaystyle T}$ may be calculated recursively:

# %% [markdown]
# $${\displaystyle S_{t}={\begin{cases}T_{0},&t=0\\\alpha T_{t}+(1-\alpha )\cdot S_{t-1},&t>0\end{cases}}}$$

# %% [markdown]
# Where:
# - The coefficient ${\displaystyle \alpha }$ represents the degree of weighting decrease, a constant smoothing factor between 0 and 1. A higher ${\displaystyle \alpha }$ discounts older observations faster.
# - ${\displaystyle T_{t}}$ is the value at a time period ${\displaystyle t}$.
# - ${\displaystyle S_{t}}$ is the value of the EMA at any time period ${\displaystyle t}$.

# %% [markdown]
# More concise way to write it:

# %% [markdown]
# $$\bar {x}_{t} = \sum_{n=0}^{+\infty} \alpha ({1-{\alpha}})^n {\bar {x}_{t-1}}$$

# %%
f.loc['1961:2019','Wheat'].plot()
df.loc['1961:2019','Wheat'].rolling(window=1, freq='Y').mean().plot(label='simple moving average',lw=3,ls=':',alpha=0.8)
df.loc['1961:2019','Wheat'].rolling(window=1, freq='Y',center=True).mean().plot(label='centered moving average',lw=3,ls=':',alpha=0.8)

#Here is our new EWMA function
df.loc['1961:2019','Wheat'].ewm(alpha=0.7).mean().plot(label='exponential weighted moving average',lw=3,ls='--')
plt.legend()
plt.show()

# %% [markdown]
# Let's compare how the function behaves for different values of $\alpha$

# %%
for x in np.arange(0.1,1,0.1):
    df.loc['1961:2019','Wheat'].ewm(alpha=i).mean().plot(label=f'ewma {i}',lw=3,ls='--')
plt.legend()
plt.show()

# %% [markdown]
# ***FIRST CONCLUSION: it appears that our time series IS NOT stationary since our rolling mean & rolling std aren't contstant over time***. We will confirm this hypothesis by using the *Augmented Dickey-Fuller statistical test*.

# %% [markdown]
# **Augmented Dickey-Fuller Test**<br/>
# The *Augmented Dickey–Fuller test* is used in time serie analysis to gives us several values which will help in identifying *stationarity*. We first define the Null hypothesis has that *"a time-series is non-stationary*. Then a  Statistics test & some critical values for some confidence levels are defined & performed. If the test is less than the certain critical values, we can reject the null hypothesis & say that the series is stationary. THE ADCF test also gives us a *p-value*. Acc to the null hypothesis, lower values of p is better.

# %%
#Augmented Dickey–Fuller test:
print('Results of Augmented Dickey Fuller test:')
dick_full_test = adfuller(indexedDataset['#Passengers'], autolag='AIC')

dick_full_output = pd.Series(dick_full_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dick_full_test[4].items():
    dick_full_output['Critical Value (%s)'%key] = value
    
print(dick_full_output)

# %% [markdown]
# To be stationary: we should have got:
# - the *p-value* as low as possible (0<p-value<1)
# - the *critical values* at the different confidence intervals should be as close as possible to the Test Statistic

# %% [markdown]
# CONCLUSION: we can see that our time-series is **NOT stationary**. Thus we need to perform some *data transformation* to it.

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# Goal: reach a ***stationary time-series***

# %% [markdown]
# **LogScale our data**

# %% [markdown]
# We first ScaleTransform our data points using the log function to flatten our spikes.

# %%
#df_logscaled = np.log(df)
#plt.plot(df_logscaled)

# %% [markdown]
# **Time Shift Transform**

# %%
#df_logscaled_shifted = df_logscaled - df_logscaled.shift()
#plt.plot(df_logscaled_shifted)

# %%
def stationarity_test(df,column):
    
    #Determine rolling statistics
    movingAverage = df[column].rolling(window=12).mean()
    movingSTD = df[column].rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(df[column], color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Augmented Dickey–Fuller test:
    print('Results of Augmented Dickey Fuller test:')
    dick_full_test = adfuller(df[column], autolag='AIC')
    dick_full_output = pd.Series(dick_full_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dick_full_test[4].items():
        dick_full_output['Critical Value (%s)'%key] = value

    print(dick_full_output)

# %%
stationarity_test(df_logscaled_shifted,'#Passengers')

# %% [markdown]
# ### Predictions/Forecasting

# %% [markdown]
# **1. State-of-the-art statistical technic: ARIMA**

# %% [markdown]
# ARIMA(Auto Regressive Integrated Moving Average) is a combination of 2 models AR(Auto Regressive) & MA(Moving Average). It has 3 hyperparameters - P(auto regressive lags),d(order of differentiation),Q(moving avg.) which respectively comes from the AR, I & MA components. The AR part is correlation between prev & current time periods. To smooth out the noise, the MA part is used. The I part binds together the AR & MA parts.

# %% [markdown]
# **How to find the best values P & Q ?**

# %% [markdown]
# We need to take help of ACF(Auto Correlation Function) & PACF(Partial Auto Correlation Function) plots. ACF & PACF graphs are used to find value of P & Q for ARIMA. We need to check, for which value in x-axis, graph line drops to 0 in y-axis for 1st time.
# - From PACF(at y=0), get P
# - From ACF(at y=0), get Q

# %% [markdown]
# **Let's plot ACF & PACF functions**

# %%
#ACF & PACF plots

lag_acf = acf(datasetLogDiffShifting, nlags=20)
lag_pacf = pacf(datasetLogDiffShifting, nlags=20, method='ols')

#Plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.title('Autocorrelation Function')            

#Plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.axhline(y=1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
            
plt.tight_layout()

# %% [markdown]
# **AR Model**

# %%
#AR Model
#making order=(2,1,0) gives RSS=1.5023
model = ARIMA(indexedDataset_logScale, order=(2,1,0))
results_AR = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_AR.fittedvalues - datasetLogDiffShifting['#Passengers'])**2))
print('Plotting AR model')

# %% [markdown]
# **MA Model**

# %%
#MA Model
model = ARIMA(indexedDataset_logScale, order=(0,1,2))
results_MA = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_MA.fittedvalues - datasetLogDiffShifting['#Passengers'])**2))
print('Plotting MA model')

# %% [markdown]
# **ARIMA: AR & MA Models Integrated**

# %%
# AR+I+MA = ARIMA model
model = ARIMA(indexedDataset_logScale, order=(2,1,2))
results_ARIMA = model.fit(disp=-1)
plt.plot(datasetLogDiffShifting)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'%sum((results_ARIMA.fittedvalues - datasetLogDiffShifting['#Passengers'])**2))
print('Plotting ARIMA model')

# %% [markdown]
# **2. LSTM Model**

# %%
## EXPLAIN HOW A LSTM NETWORK FUNCTIONS STEP BY STEP

# %% [markdown]
# ## Time Series Analysis #2: Correlation with Pop Growth Forecast

# %% [markdown]
# 1. En fonction de l'augmentation de la population, plotter la courbe d'augmentation de la pop -vs- augmentation de la production, et trouver le point de croisement entre les deux

# %% [markdown]
# **Let's consolidate the data to get only the total worldwide population per year since 1950**

# %%
world_pop = pop_df_raw[pop_df_raw['Location'] == 'World']
world_pop

# %% [markdown]
# **In order to manipulate dates in a simpler manner, let's first tweak our 'Time' column in order to be able to put it in a DateTimeIndex format**

# %%
world_pop['Time'] = world_pop['Time'].apply(lambda x: "01/01/" + str(x))
world_pop = world_pop.set_index('Time')
world_pop.index = pd.to_datetime(world_pop.index)
world_pop

# %%
#Divide estimations & constant/historical data
world_pop_estimations = world_pop['2020':]
world_pop_const = world_pop[:'2019']
world_pop_const

# %%
plt.figure(figsize=(18,10))
world_pop_const['PopTotal'].plot()
plt.show()

# %%
stationarity_test(world_pop_const,'PopTotal')

# %% [markdown]
# ## Time Series Analysis #3: CO2 Emissions Trend

# %% [markdown]
# **Using RandomForests**

# %% [markdown]
# 1. Analyse des *feature_importances_* d'une regression linéraire sur les prédictions établies par la FAO sur les émissions de CO2

# %% [markdown]
# 2. Utilisation de ces informations pour construire une time-series analysis et prédire une trend à horizon 2050

# %% [markdown]
# 3. Comparer ces résultats avec les estimations de la FAO

# %% [markdown]
# # Conclusion

# %% [markdown]
# Of course these predictions are to be put into perspective and context. Climate change, and more recently Ukrainian war dismantle such algorithms. Such hazards, natural and man-made disasters lead to huge changes in food production. And it is undermining our ability to predict crop yields. Even the best models break down in this context.
